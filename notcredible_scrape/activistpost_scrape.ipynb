# %%
import requests
import json
import os
from bs4 import BeautifulSoup
from datetime import datetime
import newspaper

# %%
source = 'activistpost'
month = '03'
days = [str(i) for i in list(range(1,10))]

dates = []
for day in days:
    dates.append("{0}-0{1}".format(month, day))

# %%
for date in dates:
    # Load HTML
    filepath = '/mnt/c/Users/Brennan/Dropbox/MIDS/w210-capstone/data/notCredible/{0}/{1}.html'.format(source,date)
    with open(filepath) as f:
        soup = BeautifulSoup(f, 'lxml')

    # Pull out article links that were published on date
    links = []
    i=0

    for div in soup.findAll('div', attrs={'class':'home-columns'}):
        for article in div.findAll('article'):
            for p in div.findAll('p', attrs={'class':'entry-meta'}):
                for span in p.findAll('span', attrs={'class':'entry-meta-date updated'}):
                    pubdate = datetime.strptime(span.text, "%B %d, %Y")
                    if date in str(pubdate):
                        for header in article.findAll('h3'):
                            for link in header.findAll('a'):
                                links.append(link.get('href'))

    links = set(links)
    links = list(links)
    
    for link in links:
        link = newspaper.Article(link)
        link.download()
        html = link.html
        link.parse()
        date_longform = '{0}-2017'.format(date)
        
        article = {}
        article["html"] = html
        article["title"] = link.title
        article["url"] = link.url
        article["date"] = date_longform
        article["source"] = source
        article["text"] = link.text
        article["images"] = list(link.images)
        article["videos"] = link.movies

        outfile = '/mnt/c/Users/Brennan/Dropbox/MIDS/w210-capstone/data/notCredible/{0}/articles/{2}/article{1}_{2}.txt'.format(source,i,date)
        os.makedirs(os.path.dirname(outfile), exist_ok=True)
        i+=1

        with open(outfile, 'w') as f:
            json.dump(article, f)

# %%
#Test that articles saved correctly
with open('/mnt/c/Users/Brennan/Dropbox/MIDS/w210-capstone/data/notCredible/activistpost/articles/02-18/article0_02-18.txt') as json_data:
    d = json.load(json_data)
    
print(d["title"])
print()
print(d["source"])
print()
print(d["url"])
print()
print(d["date"])
print()
print(d["text"])
print()
print(d["images"])
print()
print(d["videos"])
print()
print(d["html"])
# Out:
# Did the Trump/Johnson Effect Destroy Libertarianism?
#
# activistpost
#
# http://www.activistpost.com/2017/02/trumpjohnson-effect-destroy-libertarianism.html
#
# 02-18-2017
#
# By Adam Kokesh
#
# It’s been so sad to see so many so called libertarians drifting away from the message. Adam Kokesh delivers epic rant about anarchists and libertarians becoming statists under Trump.
#
# Visit TheFreedomLine.com
#
# ['http://www.activistpost.com/wp-content/uploads/2017/03/high-level-pedos-120x67.jpg', 'http://www.activistpost.com/wp-content/uploads/2017/02/gary_johnson_donald_trump.png', 'http://www.activistpost.com/wp-content/uploads/2016/04/Allegory-cave-120x67.jpg', 'http://www.activistpost.com/wp-content/uploads/2017/03/smart-city-surveillance-1024x590-1-120x67.jpg', 'http://www.activistpost.com/wp-content/uploads/2017/03/empty-stroller-vaccine-walk-2017-120x67.jpg', 'https://www.facebook.com/tr?id=1618838608380074&ev=PageView&noscript=1', 'http://www.activistpost.com/wp-content/uploads/2017/03/10K-3d-printed-house-120x67.jpg', 'http://www.activistpost.com/wp-content/uploads/2016/11/sessions-trump-120x67.jpg', 'http://www.activistpost.com/wp-content/uploads/2017/03/darpa-mind-control-120x67.jpg', 'http://www.activistpost.com/wp-content/uploads/2016/06/1984-thumbnail-manual-120x67.jpg', 'http://www.activistpost.com/wp-content/uploads/2012/01/Nikola-Tesla-120x67.jpg', 'http://www.activistpost.com/wp-content/uploads/2017/03/big-brother-media-120x67.jpg']
#
# ['https://www.youtube.com/embed/z_grO2ISqZQ?feature=oembed']
#
# <!DOCTYPE html>
# <html class="no-js" lang="en-US" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
# <head>
# <meta charset="UTF-8">
# <title>Did the Trump/Johnson Effect Destroy Libertarianism?</title>
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <link rel="profile" href="http://gmpg.org/xfn/11" />
# <link rel="pingback" href="http://www.activistpost.com/xmlrpc.php" />
#
# <!-- This site is optimized with the Yoast SEO plugin v4.4 - https://yoast.com/wordpress/plugins/seo/ -->
# <link rel="canonical" href="http://www.activistpost.com/2017/02/trumpjohnson-effect-destroy-libertarianism.html" />
# <meta property="og:locale" content="en_US" />
# <meta property="og:type" content="article" />
# <meta property="og:title" content="Did the Trump/Johnson Effect Destroy Libertarianism?" />
# <meta property="og:description" content="By Adam Kokesh It&#8217;s been so sad to see so many so called libertarians drifting away from the message. Adam Kokesh delivers epic rant about..." />
# <meta property="og:url" content="http://www.activistpost.com/2017/02/trumpjohnson-effect-destroy-libertarianism.html" />
# <meta property="og:site_name" content="Activist Post" />
# <meta property="article:publisher" content="http://www.facebook.com/activistpost" />
# <meta property="article:author" content="http://www.facebook.com/activistpost" />
# <meta property="article:tag" content="Adam Kokesh" />
# <meta property="article:tag" content="Anarchism" />
# <meta property="article:tag" content="Libertarian" />
# <meta property="article:tag" content="Philosophy" />
# <meta property="article:tag" content="Voluntaryism" />
# <meta property="article:section" content="Liberty" />
# <meta property="article:published_time" content="2017-02-18T06:03:25+00:00" />
# <meta property="article:modified_time" content="2017-02-18T08:15:06+00:00" />
# <meta property="og:updated_time" content="2017-02-18T08:15:06+00:00" />
# <meta property="fb:app_id" content="760260744092114" />
# <meta property="og:image" content="http://www.activistpost.com/wp-content/uploads/2017/02/gary_johnson_donald_trump.png" />
# <meta property="og:image:width" content="744" />
# <meta property="og:image:height" content="416" />
# <meta name="twitter:card" content="summary_large_image" />
# <meta name="twitter:description" content="By Adam Kokesh It&#8217;s been so sad to see so many so called libertarians drifting away from the message. Adam Kokesh delivers epic rant about..." />
# <meta name="twitter:title" content="Did the Trump/Johnson Effect Destroy Libertarianism?" />
# <meta name="twitter:site" content="@activistpost" />
# <meta name="twitter:image" content="http://www.activistpost.com/wp-content/uploads/2017/02/gary_johnson_donald_trump.png" />
# <meta name="twitter:creator" content="@ActivistPost" />
# <!-- / Yoast SEO plugin. -->
#
# <link rel='dns-prefetch' href='//www.activistpost.com' />
# <link rel='dns-prefetch' href='//maxcdn.bootstrapcdn.com' />
# <link rel='dns-prefetch' href='//fonts.googleapis.com' />
# <link rel='dns-prefetch' href='//s.w.org' />
# <link rel="alternate" type="application/rss+xml" title="Activist Post &raquo; Feed" href="http://www.activistpost.com/feed" />
# <link rel="alternate" type="application/rss+xml" title="Activist Post &raquo; Comments Feed" href="http://www.activistpost.com/comments/feed" />
# <link rel="alternate" type="application/rss+xml" title="Activist Post &raquo; Did the Trump/Johnson Effect Destroy Libertarianism? Comments Feed" href="http://www.activistpost.com/2017/02/trumpjohnson-effect-destroy-libertarianism.html/feed" />
# 		<script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/2.2.1\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/2.2.1\/svg\/","svgExt":".svg","source":{"concatemoji":"http:\/\/www.activistpost.com\/wp-includes\/js\/wp-emoji-release.min.js?ver=4.7.3"}};
# 			!function(a,b,c){function d(a){var b,c,d,e,f=String.fromCharCode;if(!k||!k.fillText)return!1;switch(k.clearRect(0,0,j.width,j.height),k.textBaseline="top",k.font="600 32px Arial",a){case"flag":return k.fillText(f(55356,56826,55356,56819),0,0),!(j.toDataURL().length<3e3)&&(k.clearRect(0,0,j.width,j.height),k.fillText(f(55356,57331,65039,8205,55356,57096),0,0),b=j.toDataURL(),k.clearRect(0,0,j.width,j.height),k.fillText(f(55356,57331,55356,57096),0,0),c=j.toDataURL(),b!==c);case"emoji4":return k.fillText(f(55357,56425,55356,57341,8205,55357,56507),0,0),d=j.toDataURL(),k.clearRect(0,0,j.width,j.height),k.fillText(f(55357,56425,55356,57341,55357,56507),0,0),e=j.toDataURL(),d!==e}return!1}function e(a){var c=b.createElement("script");c.src=a,c.defer=c.type="text/javascript",b.getElementsByTagName("head")[0].appendChild(c)}var f,g,h,i,j=b.createElement("canvas"),k=j.getContext&&j.getContext("2d");for(i=Array("flag","emoji4"),c.supports={everything:!0,everythingExceptFlag:!0},h=0;h<i.length;h++)c.supports[i[h]]=d(i[h]),c.supports.everything=c.supports.everything&&c.supports[i[h]],"flag"!==i[h]&&(c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&c.supports[i[h]]);c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&!c.supports.flag,c.DOMReady=!1,c.readyCallback=function(){c.DOMReady=!0},c.supports.everything||(g=function(){c.readyCallback()},b.addEventListener?(b.addEventListener("DOMContentLoaded",g,!1),a.addEventListener("load",g,!1)):(a.attachEvent("onload",g),b.attachEvent("onreadystatechange",function(){"complete"===b.readyState&&c.readyCallback()})),f=c.source||{},f.concatemoji?e(f.concatemoji):f.wpemoji&&f.twemoji&&(e(f.twemoji),e(f.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# 		<style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link rel='stylesheet' id='google-language-translator-css'  href='http://www.activistpost.com/wp-content/plugins/google-language-translator/css/style.css?ver=4.7.3' type='text/css' media='all' />
# <link rel='stylesheet' id='contact-form-7-css'  href='http://www.activistpost.com/wp-content/plugins/contact-form-7/includes/css/styles.css?ver=4.7' type='text/css' media='all' />
# <link rel='stylesheet' id='elm-owl-css-css'  href='http://www.activistpost.com/wp-content/plugins/content-randomizer/assets/css/owl.carousel.min.css?ver=4.7.3' type='text/css' media='all' />
# <link rel='stylesheet' id='easyazonpro-bootstrap-popovers-css'  href='http://www.activistpost.com/wp-content/plugins/easyazon-pro-4.0.13/vendor/bootstrap.min.css?ver=3.3.2' type='text/css' media='all' />
# <link rel='stylesheet' id='easyazonpro-popovers-css'  href='http://www.activistpost.com/wp-content/plugins/easyazon-pro-4.0.13/components/popovers/resources/popovers.css?ver=4.0.13' type='text/css' media='all' />
# <link rel='stylesheet' id='mh-newsdesk-parent-style-css'  href='http://www.activistpost.com/wp-content/themes/mh_newsdesk/style.css?ver=4.7.3' type='text/css' media='all' />
# <link rel='stylesheet' id='mh-newsdesk-child-style-css'  href='http://www.activistpost.com/wp-content/themes/mh_newsdesk_child/style.css?ver=4.7.3' type='text/css' media='all' />
# <link rel='stylesheet' id='mh-style-css'  href='http://www.activistpost.com/wp-content/themes/mh_newsdesk_child/style.css?ver=1.1.0' type='text/css' media='all' />
# <link rel='stylesheet' id='mh-font-awesome-css'  href='//maxcdn.bootstrapcdn.com/font-awesome/4.3.0/css/font-awesome.min.css' type='text/css' media='all' />
# <link rel='stylesheet' id='mh-google-fonts-css'  href='//fonts.googleapis.com/css?family=PT+Serif:300,400,400italic,600,700|Oswald:300,400,400italic,600,700' type='text/css' media='all' />
# <link rel='stylesheet' id='easy-social-share-buttons-nativeskinned-css'  href='http://www.activistpost.com/wp-content/plugins/easy-social-share-buttons3/assets/css/essb-native-skinned.min.css?ver=4.1' type='text/css' media='all' />
# <link rel='stylesheet' id='easy-social-share-buttons-css'  href='http://www.activistpost.com/wp-content/plugins/easy-social-share-buttons3/assets/css/easy-social-share-buttons.min.css?ver=4.1' type='text/css' media='all' />
# <link rel='stylesheet' id='easy-social-share-buttons-display-methods-css'  href='http://www.activistpost.com/wp-content/plugins/easy-social-share-buttons3/assets/css/essb-display-methods.min.css?ver=4.1' type='text/css' media='all' />
# <link rel='stylesheet' id='essb-social-followers-counter-css'  href='http://www.activistpost.com/wp-content/plugins/easy-social-share-buttons3/lib/modules/social-followers-counter/assets/css/essb-followers-counter.min.css?ver=4.1' type='text/css' media='all' />
# <link rel='stylesheet' id='mc4wp-form-themes-css'  href='http://www.activistpost.com/wp-content/plugins/mailchimp-for-wp/assets/css/form-themes.min.css?ver=4.0.13' type='text/css' media='all' />
# <link rel='stylesheet' id='sccss_style-css'  href='http://www.activistpost.com?sccss=1&#038;ver=4.7.3' type='text/css' media='all' />
# <script type='text/javascript' src='http://www.activistpost.com/wp-includes/js/jquery/jquery.js?ver=1.12.4'></script>
# <script type='text/javascript' src='http://www.activistpost.com/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1'></script>
# <script type='text/javascript' src='http://www.activistpost.com/wp-content/plugins/google-language-translator/js/load-flags.js?ver=4.7.3'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var ajax_tptn_tracker = {"ajax_url":"http:\/\/www.activistpost.com\/wp-admin\/admin-ajax.php","top_ten_nonce":"989cd25f9d","top_ten_id":"148756","top_ten_blog_id":"1","activate_counter":"10","tptn_rnd":"1371385656"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='http://www.activistpost.com/wp-content/plugins/top-10/includes/js/top-10-tracker.js?ver=4.7.3'></script>
# <script type='text/javascript' src='http://www.activistpost.com/wp-content/themes/mh_newsdesk/js/scripts.js?ver=4.7.3'></script>
# <link rel='https://api.w.org/' href='http://www.activistpost.com/wp-json/' />
# <link rel="EditURI" type="application/rsd+xml" title="RSD" href="http://www.activistpost.com/xmlrpc.php?rsd" />
# <link rel="wlwmanifest" type="application/wlwmanifest+xml" href="http://www.activistpost.com/wp-includes/wlwmanifest.xml" />
# <meta name="generator" content="WordPress 4.7.3" />
# <meta name="generator" content="Seriously Simple Podcasting 1.15.1" />
# <link rel='shortlink' href='http://www.activistpost.com/?p=148756' />
# <link rel="alternate" type="application/json+oembed" href="http://www.activistpost.com/wp-json/oembed/1.0/embed?url=http%3A%2F%2Fwww.activistpost.com%2F2017%2F02%2Ftrumpjohnson-effect-destroy-libertarianism.html" />
# <link rel="alternate" type="text/xml+oembed" href="http://www.activistpost.com/wp-json/oembed/1.0/embed?url=http%3A%2F%2Fwww.activistpost.com%2F2017%2F02%2Ftrumpjohnson-effect-destroy-libertarianism.html&#038;format=xml" />
# <style type="text/css">.goog-te-gadget {
#     float: left;
# }.goog-tooltip {display: none !important;}.goog-tooltip:hover {display: none !important;}.goog-text-highlight {background-color: transparent !important; border: none !important; box-shadow: none !important;}#google_language_translator a {display: none !important; }.goog-te-gadget {color:transparent !important;}.goog-te-gadget { font-size:0px !important; }.goog-branding { display:none; }#flags { display:none; }.goog-te-banner-frame{visibility:hidden !important;}body { top:0px !important;}</style><script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
# ga('provide', 'adblockTracker', function(tracker, opts) {
#   var ad = document.createElement('ins');
#   ad.className = 'AdSense';
#   ad.style.display = 'block';
#   ad.style.position = 'absolute';
#   ad.style.top = '-1px';
#   ad.style.height = '1px';
#   document.body.appendChild(ad);
#   tracker.set('dimension' + opts.dimensionIndex, !ad.clientHeight);
#   document.body.removeChild(ad);
# });
#
#   ga('create', 'UA-7598856-7', 'auto');
#   ga('require', 'adblockTracker', {dimensionIndex: 2});
#   ga('send', 'pageview');
#
# </script>
#
# <script type='text/javascript' src='//hi.districtm.ca/v3.0.104838.js'></script>
# <script type='text/javascript' src='//hi.districtm.ca/currency.js'></script>
# <script type='text/javascript' src='//cdn.districtm.ca/v4.0.header.min.js'></script>
#
# <script async='async' src='https://www.googletagservices.com/tag/js/gpt.js'></script>
# <script>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
# </script>
#
# <script>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/9716847/AP-336x280-1', [[336, 280], [300, 250]], 'div-gpt-ad-1470694951173-0').addService(googletag.pubads());
#     googletag.defineSlot('/9716847/AP-336x280-5', [[336, 280], [300, 250]], 'div-gpt-ad-1470694951173-1').addService(googletag.pubads());
#     googletag.defineSlot('/9716847/AP-336x280-2', [[336, 280], [300, 250]], 'div-gpt-ad-1470694951173-2').addService(googletag.pubads());
#     googletag.defineSlot('/9716847/AP-336x280-3', [[336, 280], [300, 250]], 'div-gpt-ad-1470694951173-3').addService(googletag.pubads());
#     googletag.defineSlot('/9716847/EndOfArticle728x90', [728, 90], 'div-gpt-ad-1470694951173-6').addService(googletag.pubads());
#     googletag.defineSlot('/9716847/Footer-Ads', [[728, 90], [320, 100]], 'div-gpt-ad-1470694951173-7').addService(googletag.pubads());
#     googletag.defineSlot('/9716847/AP-336x280-4', [[336, 280], [300, 250]], 'div-gpt-ad-1470694951173-4').addService(googletag.pubads());
#     googletag.defineSlot('/9716847/AP-Content', [300, 250], 'div-gpt-ad-1470694951173-5').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script>
#
#
# <meta property="fb:pages" content="128407570539436" />
# <meta name="earnify-site-verification" content="167a1cbe4437e4c4bd12137fbe5005e73085021c" />
# <meta name="google-site-verification" content="NlBqUS9zex0hZ4hjEniXeukxex2aiWfF0QvHmMJcwFQ" />
# <meta name="bitly-verification" content="f2d5d260f01c"/>
#
# <!-- Facebook Pixel Code -->
# <script>
# !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# document,'script','//connect.facebook.net/en_US/fbevents.js');
#
# fbq('init', '1618838608380074');
# fbq('track', "PageView");</script>
# <noscript><img height="1" width="1" style="display:none"
# src="https://www.facebook.com/tr?id=1618838608380074&ev=PageView&noscript=1"
# /></noscript>
# <!-- End Facebook Pixel Code -->
#
# <script src="https://apis.google.com/js/platform.js"></script>
#
# <div id="fb-root"></div>
# <script>(function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/en_US/sdk.js#xfbml=1&version=v2.7&appId=799509616835812";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));</script>
#
#
# <!-- <div id="contentad161440"></div>
# <script type="text/javascript">
#     (function(d) {
#         var params =
#         {
#             id: "b90fd6c9-f06e-4e3b-a750-414d611dfe1a",
#             d:  "YWN0aXZpc3Rwb3N0LmNvbQ==",
#             wid: "161440",
#             exitPopMobile: true,
#             cb: (new Date()).getTime()
#         };
#
#         var qs=[];
#         for(var key in params) qs.push(key+'='+encodeURIComponent(params[key]));
#         var s = d.createElement('script');s.type='text/javascript';s.async=true;
#         var p = 'https:' == document.location.protocol ? 'https' : 'http';
#         s.src = p + "://api.content.ad/Scripts/widget2.aspx?" + qs.join('&');
#         d.getElementById("contentad161440").appendChild(s);
#     })(document);
# </script> -->
#
# <script src="https://eightlabels.com/external/apost_epm.js"></script>
#
# <!-- nativeads pixel 107041-activistpost.com start -->
# <script type="text/javascript" src="//cpanel.nativeads.com/js/pixel/pixel-107041-1a60bc7e17376fce06f189e6d88fc8aaef0780a2.js"></script>
# <!-- nativeads pixel 107041-activistpost.com end -->
#
# <!-- nativeads 107041-activistpost.com-imageAds 2017-01-09 407072 start -->
# <!--<script type="text/javascript" src="//cpanel.nativeads.com/js/nativeads-107041-233e542cc28f40640f885c24b177a978c5f43825.js" async></script> -->
# <!-- nativeads 107041-activistpost.com-imageAds 2017-01-09 407072 end -->
#
# <!-- nativeads 107041-activistpost.com-imageAds 2017-01-09 807890 start -->
# <!--<script type="text/javascript" src="//cpanel.nativeads.com/js/nativeads-107041-668818e4db37033f514edb3d17f980ebecd2ea60.js" async></script> -->
# <!-- nativeads 107041-activistpost.com-imageAds 2017-01-09 807890 end -->
#
# <!-- Plugin: Open external links a new window. Plugin by Kristian Risager Larsen, http://kristianrisagerlarsen.dk . Download it at http://wordpress.org/extend/plugins/open-external-links-in-a-new-window/ -->
# <script type="text/javascript">//<![CDATA[
# 	function external_links_in_new_windows_loop() {
# 		if (!document.links) {
# 			document.links = document.getElementsByTagName('a');
# 		}
# 		var change_link = false;
# 		var force = '';
# 		var ignore = '';
#
# 		for (var t=0; t<document.links.length; t++) {
# 			var all_links = document.links[t];
# 			change_link = false;
#
# 			if(document.links[t].hasAttribute('onClick') == false) {
# 				// forced if the address starts with http (or also https), but does not link to the current domain
# 				if(all_links.href.search(/^http/) != -1 && all_links.href.search('www.activistpost.com') == -1) {
# 					// alert('Changeda '+all_links.href);
# 					change_link = true;
# 				}
#
# 				if(force != '' && all_links.href.search(force) != -1) {
# 					// forced
# 					// alert('force '+all_links.href);
# 					change_link = true;
# 				}
#
# 				if(ignore != '' && all_links.href.search(ignore) != -1) {
# 					// alert('ignore '+all_links.href);
# 					// ignored
# 					change_link = false;
# 				}
#
# 				if(change_link == true) {
# 					// alert('Changed '+all_links.href);
# 					document.links[t].setAttribute('onClick', 'javascript:window.open(\''+all_links.href+'\'); return false;');
# 					document.links[t].removeAttribute('target');
# 				}
# 			}
# 		}
# 	}
#
# 	// Load
# 	function external_links_in_new_windows_load(func)
# 	{
# 		var oldonload = window.onload;
# 		if (typeof window.onload != 'function'){
# 			window.onload = func;
# 		} else {
# 			window.onload = function(){
# 				oldonload();
# 				func();
# 			}
# 		}
# 	}
#
# 	external_links_in_new_windows_load(external_links_in_new_windows_loop);
# 	//]]></script>
#
#
# <link rel="alternate" type="application/rss+xml" title="Podcast RSS feed" href="http://www.activistpost.com/feed/podcast" />
#
# <style type="text/css">img.tptn_thumb {
#     width: 120px !important;
#     height: 67px !important;
#     display: block;
#     float: left;
#     clear: left;
#     margin-right: 10px !important;
#     padding: 3px !important;
#     border: none;
# }
#
# .tptn_posts_daily .tptn_title, .tptn_posts .tptn_title {
#     display: block;
#     padding-bottom: 5px;
#     text-decoration: none;
#     line-height: 1.1em;
#     font-size: 1rem;
#     overflow: hidden;
#     font-family: "Oswald",Helvetica,Arial,sans-serif;
#     font-weight: normal;
# }
#
# img.tptn_thumb {
#     vertical-align: bottom;
#     box-shadow: 0px 0px 0px 0px;
#     border-radius: 0px;
# }
#
# .tptn_date {
#     margin: 0px;
#     padding: 0px;
#     border: 0px none;
#     font-family: "Oswald",Helvetica,Arial,sans-serif;
#     vertical-align: baseline;
#    font-size: 0.75rem;
#    text-transform: uppercase;
# }</style><link rel="shortcut icon" href="http://www.activistpost.com/wp-content/uploads/2015/08/FC1.png">
# <!--[if lt IE 9]>
# <script src="http://www.activistpost.com/wp-content/themes/mh_newsdesk/js/css3-mediaqueries.js"></script>
# <![endif]-->
# <style type="text/css">.essb-native-text .essb-native-text-inner { font-size: 17px; } .essb-native-facebook .essb-native-text { text-align: left; padding-left: 15px; font-family: "Oswald",Helvetica,Arial,sans-serif; } .essb-native-facebook { height: 34px; width: 350px; } .essb-native-twitter { height: 34px; width: 350px; } .essb-native-twitter .essb-native-text { text-align: left; padding-left: 15px; font-family: "Oswald",Helvetica,Arial,sans-serif; }</style>
# <script type="text/javascript">var essb_settings = {"ajax_url":"http:\/\/www.activistpost.com\/wp-admin\/admin-ajax.php","essb3_nonce":"81b9753a43","essb3_plugin_url":"http:\/\/www.activistpost.com\/wp-content\/plugins\/easy-social-share-buttons3","essb3_facebook_total":true,"essb3_admin_ajax":false,"essb3_internal_counter":false,"essb3_stats":false,"essb3_ga":true,"essb3_ga_mode":"simple","essb3_counter_button_min":50,"essb3_counter_total_min":0,"blog_url":"http:\/\/www.activistpost.com\/","ajax_type":"wp","essb3_postfloat_stay":false,"essb3_no_counter_mailprint":false,"essb3_single_ajax":false,"twitter_counter":"self","post_id":148756};</script></head>
# <body class="post-template-default single single-post postid-148756 single-format-standard mh-right-sb">
# 	<div class="header-top">
# 		<div class="wrapper-inner clearfix">
# 							<nav class="header-nav clearfix">
# 					<div class="menu-top-menu-container"><ul id="menu-top-menu" class="menu"><li id="menu-item-64736" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-64736"><a href="http://www.activistpost.com/contact-us">Contact Us</a></li>
# <li id="menu-item-64732" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-64732"><a href="http://www.activistpost.com/support">Support Us</a></li>
# <li id="menu-item-64734" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-64734"><a href="http://www.activistpost.com/contributors">Contributors</a></li>
# <li id="menu-item-78068" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-78068"><a href="http://www.activistpost.com/resources">Resources</a></li>
# <li id="menu-item-111269" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-111269"><a href="http://www.activistpost.com/reading-list">Reading List</a></li>
# <li id="menu-item-114649" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-114649"><a href="http://www.activistpost.com/survive-economic-collapse-in-2017">Survival</a></li>
# </ul></div>				</nav>
# 										<nav class="social-nav clearfix">
# 					<div id="flags" class="size18"><ul id="sortable" class="ui-sortable" style="float:left"><li id='English'><a title='English' class='notranslate flag en English'></a></li></ul></div><div id="google_language_translator"></div><div class="menu-social-icons-container"><ul id="menu-social-icons" class="menu"><li id="menu-item-64740" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-64740"><a href="http://www.twitter.com/ActivistPost"><span class="fa-stack"><i class="fa fa-circle fa-stack-2x"></i><i class="fa fa-mh-social fa-stack-1x"></i></span><span class="screen-reader-text">Twitter</span></a></li>
# <li id="menu-item-64741" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-64741"><a href="http://www.facebook.com/activistpost?v=wall"><span class="fa-stack"><i class="fa fa-circle fa-stack-2x"></i><i class="fa fa-mh-social fa-stack-1x"></i></span><span class="screen-reader-text">Facebook</span></a></li>
# <li id="menu-item-64742" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-64742"><a href="http://www.youtube.com/activistpost"><span class="fa-stack"><i class="fa fa-circle fa-stack-2x"></i><i class="fa fa-mh-social fa-stack-1x"></i></span><span class="screen-reader-text">YouTube</span></a></li>
# <li id="menu-item-71756" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-71756"><a href="http://feeds.feedburner.com/ActivistPost"><span class="fa-stack"><i class="fa fa-circle fa-stack-2x"></i><i class="fa fa-mh-social fa-stack-1x"></i></span><span class="screen-reader-text">RSS</span></a></li>
# </ul></div>				</nav>
# 					</div>
# 	</div>
# <div id="mh-wrapper">
# <header class="mh-header">
# 	<div class="header-wrap clearfix">
# 				<div class="mh-col mh-1-3 header-logo">
# 			<a href="http://www.activistpost.com/" title="Activist Post" rel="home">
# <div class="logo-wrap" role="banner">
# <div class="logo">
# <h1 class="logo-title">Activist Post</h1>
# <h2 class="logo-tagline">Propaganda for Peace, Love, and Liberty</h2>
# </div>
# </div>
# </a>
# 		</div>
# 		<aside class="mh-col mh-2-3"><div class="header-ad">			<div class="textwidget"><script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- AP WP Responsive Header -->
# <ins class="adsbygoogle"
#      style="display:block"
#      data-ad-client="ca-pub-1897954795849722"
#      data-ad-slot="2777215868"
#      data-ad-format="auto"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script></div>
# 		</div></aside>	</div>
# 	<div class="header-menu clearfix">
# 		<nav class="main-nav clearfix">
# 			<div class="menu-main-menu-container"><ul id="menu-main-menu" class="menu"><li id="menu-item-64712" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-home menu-item-64712"><a href="http://www.activistpost.com/">Home</a></li>
# <li id="menu-item-64727" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-64727"><a href="http://www.activistpost.com/category/economy">Economy</a></li>
# <li id="menu-item-64720" class="menu-item menu-item-type-taxonomy menu-item-object-category current-post-ancestor current-menu-parent current-post-parent menu-item-64720"><a href="http://www.activistpost.com/category/liberty">Liberty</a></li>
# <li id="menu-item-64725" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-64725"><a href="http://www.activistpost.com/category/war">War</a></li>
# <li id="menu-item-64719" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-64719"><a href="http://www.activistpost.com/category/activism">Activism</a></li>
# <li id="menu-item-64729" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-64729"><a href="http://www.activistpost.com/category/health">Health</a></li>
# <li id="menu-item-64730" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-64730"><a href="http://www.activistpost.com/category/technology">Technology</a></li>
# <li id="menu-item-64726" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-64726"><a href="http://www.activistpost.com/category/environment">Environment</a></li>
# <li id="menu-item-70169" class="menu-item menu-item-type-taxonomy menu-item-object-category current-post-ancestor current-menu-parent current-post-parent menu-item-70169"><a href="http://www.activistpost.com/category/video">Video</a></li>
# <li id="menu-item-144073" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-144073"><a href="http://www.activistpost.com/podcast">Podcasts</a></li>
# </ul></div>		</nav>
# 		<div class="header-sub clearfix">
# 							<section id="ticker" class="news-ticker mh-col mh-2-3 clearfix">
# 			<span class="ticker-title">Hot Topics</span>
# 		<ul class="ticker-content">			<li class="ticker-item">
# 				<a class="ticker-item-link" href="http://www.activistpost.com/2017/03/sound-money-rising-state-level.html" title="Sound Money Is Rising At The State Level">
# 					<span class="ticker-item-date">March 7, 2017</span>
# 					<span class="ticker-item-separator">|</span>
# 					<span class="ticker-item-title">Sound Money Is Rising At The State Level</span>
# 				</a>
# 			</li>			<li class="ticker-item">
# 				<a class="ticker-item-link" href="http://www.activistpost.com/2017/03/wikileaks-reveals-new-details-about-growing-surveillance-state.html" title="WikiLeaks Reveals New Details About Growing Surveillance State">
# 					<span class="ticker-item-date">March 7, 2017</span>
# 					<span class="ticker-item-separator">|</span>
# 					<span class="ticker-item-title">WikiLeaks Reveals New Details About Growing Surveillance State</span>
# 				</a>
# 			</li>			<li class="ticker-item">
# 				<a class="ticker-item-link" href="http://www.activistpost.com/2017/03/wikileaks-vault-7-shows-cia-spies-tv-phone-pc-mac.html" title="WikiLeaks&#8217; Vault 7 Shows How CIA Spies On Your TV, Phone, PC, Mac, And More">
# 					<span class="ticker-item-date">March 7, 2017</span>
# 					<span class="ticker-item-separator">|</span>
# 					<span class="ticker-item-title">WikiLeaks&#8217; Vault 7 Shows How CIA Spies On Your TV, Phone, PC, Mac, And More</span>
# 				</a>
# 			</li>			<li class="ticker-item">
# 				<a class="ticker-item-link" href="http://www.activistpost.com/2017/03/us-military-using-violent-chaotic-beautiful-video-games-train-soldiers.html" title="How The US Military Is Using &#8220;Violent, Chaotic, Beautiful&#8221; Video Games To Train Soldiers">
# 					<span class="ticker-item-date">March 7, 2017</span>
# 					<span class="ticker-item-separator">|</span>
# 					<span class="ticker-item-title">How The US Military Is Using &#8220;Violent, Chaotic, Beautiful&#8221; Video Games To Train Soldiers</span>
# 				</a>
# 			</li>			<li class="ticker-item">
# 				<a class="ticker-item-link" href="http://www.activistpost.com/2017/03/empty-stroller-walk-vaccine-infant-deaths-information.html" title="Empty Stroller Walk And Vaccine Infant Deaths Information">
# 					<span class="ticker-item-date">March 7, 2017</span>
# 					<span class="ticker-item-separator">|</span>
# 					<span class="ticker-item-title">Empty Stroller Walk And Vaccine Infant Deaths Information</span>
# 				</a>
# 			</li>	</ul>
# </section>						<aside class="mh-col mh-1-3 header-search">
# 				<form role="search" method="get" class="search-form" action="http://www.activistpost.com/">
# 				<label>
# 					<span class="screen-reader-text">Search for:</span>
# 					<input type="search" class="search-field" placeholder="Search &hellip;" value="" name="s" />
# 				</label>
# 				<input type="submit" class="search-submit" value="Search" />
# 			</form>			</aside>
# 		</div>
# 	</div>
# </header><div class="mh-section mh-group">
# 	<div id="main-content" class="mh-content">
# 		<nav class="breadcrumb"><span itemscope itemtype="http://data-vocabulary.org/Breadcrumb"><a href="http://www.activistpost.com" itemprop="url" class="bc-home"><span itemprop="title">Home</span></a></span> <span itemscope itemtype="http://data-vocabulary.org/Breadcrumb"><a href="http://www.activistpost.com/category/liberty" itemprop="url"><span itemprop="title">Liberty</span></a></span></nav>
# 					<article id="post-148756" class="post-148756 post type-post status-publish format-standard has-post-thumbnail hentry category-liberty category-politics category-video tag-adam-kokesh tag-anarchism tag-libertarian tag-philosophy tag-voluntaryism">
# 	<header class="entry-header clearfix">
# 		<h1 class="entry-title">Did the Trump/Johnson Effect Destroy Libertarianism?</h1>
# 		<div class="entry-tags clearfix"><span>TOPICS:</span><a href="http://www.activistpost.com/tag/adam-kokesh" rel="tag">Adam Kokesh</a><a href="http://www.activistpost.com/tag/anarchism" rel="tag">Anarchism</a><a href="http://www.activistpost.com/tag/libertarian" rel="tag">Libertarian</a><a href="http://www.activistpost.com/tag/philosophy" rel="tag">Philosophy</a><a href="http://www.activistpost.com/tag/voluntaryism" rel="tag">Voluntaryism</a></div>	</header>
# 			<p class="entry-meta">
# <span class="entry-meta-date updated">February 18, 2017</span>
# </p>
# 	<div class="entry-content clearfix">
# <script src="//pagead2.googlesyndication.com/pagead/show_ads.js"></script></div>		<p>By <a href="https://www.youtube.com/user/AdamKokesh">Adam Kokesh</a></p>
# <p>It&#8217;s been so sad to see so many so called libertarians drifting away from the message. Adam Kokesh delivers epic rant about anarchists and libertarians becoming statists under Trump.</p>
# <div class="sb-widget clearfix">			<div class="textwidget"><div align="left"><script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- AP WP Responsive -->
# <ins class="adsbygoogle"
#      style="display:block"
#      data-ad-client="ca-pub-1897954795849722"
#      data-ad-slot="4254280269"
#      data-ad-format="auto"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script></div></div>
# 		</div>
# <p><iframe width="777" height="437" src="https://www.youtube.com/embed/z_grO2ISqZQ?feature=oembed" frameborder="0" allowfullscreen></iframe></p>
# <p>Visit <a href="http://thefreedomline.com/">TheFreedomLine.com</a></p>
# <div class="essb_break_scroll"></div>	</div>
# 			<div class="advertisement">
# 			<div class="sb-widget post-ad">			<div class="textwidget"><div id="ld-6215-6164"></div><script>(function(w,d,s,i){w.ldAdInit=w.ldAdInit||[];w.ldAdInit.push({slot:8023242615045735,size:[0, 0],id:"ld-6215-6164"});if(!d.getElementById(i)){var j=d.createElement(s),p=d.getElementsByTagName(s)[0];j.async=true;j.src="//cdn2.lockerdome.com/_js/ajs.js";j.id=i;p.parentNode.insertBefore(j,p);}})(window,document,"script","ld-ajs");</script>
# <div id="8labels-daefa4582de992985f95159a39d9f97b"></div></div>
# 		</div><div class="sb-widget post-ad">			<div class="textwidget"><div class="post-ads">
# <!­­ G4__activistpostCOM_BelowPost_1Placement__other__advertising__11­09­2015 EST­­>
# <script type="text/javascript" src="http://cdn.exovueplatform.com/js/p/po2ozwf2f.js"></script>
# </div>
# </div>
# 		</div><div class="sb-widget post-ad"><h4 class="widget-title"><span>Activist Post Daily Newsletter</span></h4>			<div class="textwidget"><div class="post-ads"><div align="left"><script type="text/javascript">(function() {
# 	if (!window.mc4wp) {
# 		window.mc4wp = {
# 			listeners: [],
# 			forms    : {
# 				on: function (event, callback) {
# 					window.mc4wp.listeners.push({
# 						event   : event,
# 						callback: callback
# 					});
# 				}
# 			}
# 		}
# 	}
# })();
# </script><!-- MailChimp for WordPress v4.0.13 - https://wordpress.org/plugins/mailchimp-for-wp/ --><form id="mc4wp-form-2" class="mc4wp-form mc4wp-form-116586 mc4wp-form-theme mc4wp-form-theme-blue" method="post" data-id="116586" data-name="Default sign-up form" ><div class="mc4wp-form-fields"><p>
# 	<label>Email address: </label>
# 	<input type="email" id="mc4wp_email" name="EMAIL" placeholder="Your email address" required />
# </p>
# 	<input type="submit" value="Sign up" /><div style="display: none;"><input type="text" name="_mc4wp_honeypot" value="" tabindex="-1" autocomplete="off" /></div><input type="hidden" name="_mc4wp_timestamp" value="1488932647" /><input type="hidden" name="_mc4wp_form_id" value="116586" /><input type="hidden" name="_mc4wp_form_element_id" value="mc4wp-form-2" /></div><div class="mc4wp-response"></div></form><!-- / MailChimp for WordPress Plugin -->
# Subscription is FREE and CONFIDENTIAL<br/>
# Free Report: <i>10 Ways to Survive the Economic Collapse</i> with subscription</div></div>
# </div>
# 		</div><div class="sb-widget post-ad">			<div class="textwidget"><div class="post-ads"><!-- /9716847/EndOfArticle728x90 -->
# <div id='div-gpt-ad-1470694951173-6'>
# <script>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1470694951173-6'); });
# </script>
# </div></div></div>
# 		</div><div class="sb-widget post-ad">			<div class="textwidget"><div class="post-ads"><div class="essb_links essb_counters essb_displayed_shortcode essb_share essb_template_flat-retina essb_317273513 print-no" id="essb_displayed_shortcode_317273513" data-essb-postid="148756" data-essb-position="shortcode" data-essb-button-style="button" data-essb-template="flat-retina" data-essb-counter-pos="inside" data-essb-url="http://www.activistpost.com/2017/02/trumpjohnson-effect-destroy-libertarianism.html" data-essb-twitter-url="http://www.activistpost.com/2017/02/trumpjohnson-effect-destroy-libertarianism.html" data-essb-instance="317273513"><ul class="essb_links_list"><li class="essb_item essb_totalcount_item" style="display: none !important;" data-counter-pos="inside"><span class="essb_totalcount essb_t_l" title="Total: "><span class="essb_t_nb"></span></span></li><li class="essb_item essb_link_facebook nolightbox"> <a href="https://www.facebook.com/sharer/sharer.php?u=http://www.activistpost.com/2017/02/trumpjohnson-effect-destroy-libertarianism.html&t=Did+the+Trump%2FJohnson+Effect+Destroy+Libertarianism%3F&redirect_uri=http://www.activistpost.com?sharing-thankyou=yes" title="" onclick="essb_window(&#39;https://www.facebook.com/sharer/sharer.php?u=http://www.activistpost.com/2017/02/trumpjohnson-effect-destroy-libertarianism.html&t=Did+the+Trump%2FJohnson+Effect+Destroy+Libertarianism%3F&redirect_uri=http://www.activistpost.com?sharing-thankyou=yes&#39;,&#39;facebook&#39;,&#39;317273513&#39;); return false;" target="_blank" rel="nofollow" ><span class="essb_icon essb_icon_facebook"></span><span class="essb_network_name"></span></a></li><li class="essb_item essb_link_twitter nolightbox"> <a href="#" title="" onclick="essb_window(&#39;https://twitter.com/intent/tweet?text=Did+the+Trump%2FJohnson+Effect+Destroy+Libertarianism%3F&amp;url=http://bit.ly/2lg2zhD&amp;counturl=http://www.activistpost.com/2017/02/trumpjohnson-effect-destroy-libertarianism.html&amp;related=activistpost&amp;via=activistpost&amp;hashtags=news&#39;,&#39;twitter&#39;,&#39;317273513&#39;); return false;" target="_blank" rel="nofollow" ><span class="essb_icon essb_icon_twitter"></span><span class="essb_network_name"></span></a></li><li class="essb_item essb_link_google nolightbox"> <a href="https://plus.google.com/share?url=http://www.activistpost.com/2017/02/trumpjohnson-effect-destroy-libertarianism.html" title="" onclick="essb_window(&#39;https://plus.google.com/share?url=http://www.activistpost.com/2017/02/trumpjohnson-effect-destroy-libertarianism.html&#39;,&#39;google&#39;,&#39;317273513&#39;); return false;" target="_blank" rel="nofollow" ><span class="essb_icon essb_icon_google"></span><span class="essb_network_name"></span></a></li><li class="essb_item essb_link_reddit nolightbox"> <a href="http://reddit.com/submit?url=http://www.activistpost.com/2017/02/trumpjohnson-effect-destroy-libertarianism.html&amp;title=Did+the+Trump%2FJohnson+Effect+Destroy+Libertarianism%3F" title="" onclick="essb_window(&#39;http://reddit.com/submit?url=http://www.activistpost.com/2017/02/trumpjohnson-effect-destroy-libertarianism.html&amp;title=Did+the+Trump%2FJohnson+Effect+Destroy+Libertarianism%3F&#39;,&#39;reddit&#39;,&#39;317273513&#39;); return false;" target="_blank" rel="nofollow" ><span class="essb_icon essb_icon_reddit"></span><span class="essb_network_name"></span></a></li><li class="essb_item essb_link_pinterest nolightbox"> <a href="#" title="" onclick="essb_pinterest_picker(&#39;317273513&#39;); return false;" target="_blank" rel="nofollow" ><span class="essb_icon essb_icon_pinterest"></span><span class="essb_network_name"></span></a></li><li class="essb_item essb_link_mail nolightbox"> <a href="#" title="" onclick="essb_open_mailform(&#39;317273513&#39;); return false;" target="_blank" rel="nofollow" ><span class="essb_icon essb_icon_mail"></span><span class="essb_network_name"></span></a></li><li class="essb_item essb_link_more_dots nolightbox"> <a href="#" t ...
# 		</div>		</div>
# 	</article>						<nav class="post-nav-wrap" role="navigation">
# <ul class="post-nav clearfix">
# <li class="post-nav-prev">
# <a href="http://www.activistpost.com/2017/02/20th-century-fox-apologizes-purposely-spreading-fake-news.html" rel="prev"><i class="fa fa-chevron-left"></i>Previous post</a></li>
# <li class="post-nav-next">
# <a href="http://www.activistpost.com/2017/02/nsa-real-president-united-states.html" rel="next">Next post<i class="fa fa-chevron-right"></i></a></li>
# </ul>
# </nav>
#
# <div id="disqus_thread">
#             <div id="dsq-content">
#
#
#             <ul id="dsq-comments">
#                     <li class="comment even thread-even depth-1" id="dsq-comment-68793">
#         <div id="dsq-comment-header-68793" class="dsq-comment-header">
#             <cite id="dsq-cite-68793">
#                 <span id="dsq-author-user-68793">John Cokos</span>
#             </cite>
#         </div>
#         <div id="dsq-comment-body-68793" class="dsq-comment-body">
#             <div id="dsq-comment-message-68793" class="dsq-comment-message"><p>Adam: Good taking points. Your rant is why I no longer call myself a Libertarian. It&#8217;s washed over Republican Politics.<br />
#    Come over to the side of Nihilism and cut loose all the political ties. Semper Fi !</p>
# </div>
#         </div>
#
#     </li><!-- #comment-## -->
#     <li class="comment odd alt thread-odd thread-alt depth-1" id="dsq-comment-68796">
#         <div id="dsq-comment-header-68796" class="dsq-comment-header">
#             <cite id="dsq-cite-68796">
#                 <span id="dsq-author-user-68796">Greatgeezer</span>
#             </cite>
#         </div>
#         <div id="dsq-comment-body-68796" class="dsq-comment-body">
#             <div id="dsq-comment-message-68796" class="dsq-comment-message"><p>No, Gary Johnson did that all on his own. The anti 2nd amendment part of their platform put the nail in the coffin.</p>
# </div>
#         </div>
#
#     </li><!-- #comment-## -->
#     <li class="comment even thread-even depth-1" id="dsq-comment-68803">
#         <div id="dsq-comment-header-68803" class="dsq-comment-header">
#             <cite id="dsq-cite-68803">
#                 <span id="dsq-author-user-68803">Darkwing</span>
#             </cite>
#         </div>
#         <div id="dsq-comment-body-68803" class="dsq-comment-body">
#             <div id="dsq-comment-message-68803" class="dsq-comment-message"><p>The Libertarian Party took a 180 on a lot of issues. The state parties took a stance opposite the national party. That is why I left them. This has been going on for the past 10 years. I was a Libertarian so I could run for office, now I quit.</p>
# </div>
#         </div>
#
#     </li><!-- #comment-## -->
#     <li class="comment odd alt thread-odd thread-alt depth-1" id="dsq-comment-68836">
#         <div id="dsq-comment-header-68836" class="dsq-comment-header">
#             <cite id="dsq-cite-68836">
#                 <span id="dsq-author-user-68836">Louis Charles</span>
#             </cite>
#         </div>
#         <div id="dsq-comment-body-68836" class="dsq-comment-body">
#             <div id="dsq-comment-message-68836" class="dsq-comment-message"><p>you people keep attempting to define and debate libertarianism with words.  Sadly, Kokesh started a &#8220;homesteading project&#8221; in rural AZ, where he was setting course to LIVING libertarianism.  He was ready to SHOW us what anarchoVol libertarianism would look like (including the best way to defend oneself against an encroaching state).  What happened?  Last we heard, the county government was poised to shut the property down because of some inane &#8220;zoning&#8221; laws.  Kokesh had his day in court scheduled for sometime in Oct. &#8217;16.  THEN WHAT?  All we heard was desert crickets chirping&#8230;&#8230;  Talking about liberty is just stupid if you can&#8217;t defend your rights in an organized manner.</p>
# </div>
#         </div>
#
#     </li><!-- #comment-## -->
#     <li class="comment even thread-even depth-1" id="dsq-comment-68845">
#         <div id="dsq-comment-header-68845" class="dsq-comment-header">
#             <cite id="dsq-cite-68845">
#                 <span id="dsq-author-user-68845">WatchmanofEzekiel33</span>
#             </cite>
#         </div>
#         <div id="dsq-comment-body-68845" class="dsq-comment-body">
#             <div id="dsq-comment-message-68845" class="dsq-comment-message"><p>I have never discussed politics with any Libertarian and came away liking them.</p>
# </div>
#         </div>
#
#     </li><!-- #comment-## -->
#             </ul>
#
#
#         </div>
#
#     </div>
#
# 			</div>
# 	<aside class="mh-sidebar">
# 	<div class="sb-widget clearfix">			<div class="textwidget"><div class="ad-spot"><!-- /9716847/AP-336x280-1 -->
# <div id='div-gpt-ad-1470694951173-0'>
# <script>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1470694951173-0'); });
# </script>
# </div></div></div>
# 		</div><div class="sb-widget clearfix"><h4 class="widget-title"><span>Daily Newsletter</span></h4>			<div class="textwidget"><script type="text/javascript">(function() {
# 	if (!window.mc4wp) {
# 		window.mc4wp = {
# 			listeners: [],
# 			forms    : {
# 				on: function (event, callback) {
# 					window.mc4wp.listeners.push({
# 						event   : event,
# 						callback: callback
# 					});
# 				}
# 			}
# 		}
# 	}
# })();
# </script><!-- MailChimp for WordPress v4.0.13 - https://wordpress.org/plugins/mailchimp-for-wp/ --><form id="mc4wp-form-3" class="mc4wp-form mc4wp-form-116586 mc4wp-form-theme mc4wp-form-theme-blue" method="post" data-id="116586" data-name="Default sign-up form" ><div class="mc4wp-form-fields"><p>
# 	<label>Email address: </label>
# 	<input type="email" id="mc4wp_email" name="EMAIL" placeholder="Your email address" required />
# </p>
# 	<input type="submit" value="Sign up" /><div style="display: none;"><input type="text" name="_mc4wp_honeypot" value="" tabindex="-1" autocomplete="off" /></div><input type="hidden" name="_mc4wp_timestamp" value="1488932647" /><input type="hidden" name="_mc4wp_form_id" value="116586" /><input type="hidden" name="_mc4wp_form_element_id" value="mc4wp-form-3" /></div><div class="mc4wp-response"></div></form><!-- / MailChimp for WordPress Plugin -->
# <div class="contentsubs">Subscription is FREE and CONFIDENTIAL</div></div>
# 		</div><div class="sb-widget clearfix">			<div class="textwidget"><div class="ad-spot"><!-- /9716847/AP-336x280-5 -->
# <div id='div-gpt-ad-1470694951173-1'>
# <script>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1470694951173-1'); });
# </script>
# </div></div></div>
# 		</div><div class="sb-widget clearfix">			<div class="textwidget"><div class="ad-spot"><!-- /9716847/AP-336x280-2 -->
# <div id='div-gpt-ad-1470694951173-2'>
# <script>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1470694951173-2'); });
# </script>
# </div></div></div>
# ...
# 	for( var j=0; j < urlFields.length; j++ ) {
# 		addEventListener(urlFields[j],'blur',maybePrefixUrlField);
# 	}
# }/* test if browser supports date fields */
# var testInput = document.createElement('input');
# testInput.setAttribute('type', 'date');
# if( testInput.type !== 'date') {
#
# 	/* add placeholder & pattern to all date fields */
# 	var dateFields = document.querySelectorAll('.mc4wp-form input[type="date"]');
# 	for(var i=0; i<dateFields.length; i++) {
# 		if(!dateFields[i].placeholder) {
# 			dateFields[i].placeholder = 'YYYY-MM-DD';
# 		}
# 		if(!dateFields[i].pattern) {
# 			dateFields[i].pattern = '[0-9]{4}-(0[1-9]|1[012])-(0[1-9]|1[0-9]|2[0-9]|3[01])';
# 		}
# 	}
# }
#
# })();</script><script type='text/javascript' src='http://www.activistpost.com/wp-content/plugins/contact-form-7/includes/js/jquery.form.min.js?ver=3.51.0-2014.06.20'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var _wpcf7 = {"recaptcha":{"messages":{"empty":"Please verify that you are not a robot."}},"cached":"1"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='http://www.activistpost.com/wp-content/plugins/contact-form-7/includes/js/scripts.js?ver=4.7'></script>
# <script type='text/javascript' src='http://www.activistpost.com/wp-content/plugins/content-randomizer/assets/js/owl.carousel.min.js?ver=1.0'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var EasyAzonPro_Localize_Links = {"ajaxAction":"easyazonpro_localize","ajaxUrl":"http:\/\/www.activistpost.com\/wp-admin\/admin-ajax.php"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='http://www.activistpost.com/wp-content/plugins/easyazon-pro-4.0.13/components/localization/links/resources/links.js?ver=4.0.13'></script>
# <script type='text/javascript' src='http://www.activistpost.com/wp-content/plugins/easyazon-pro-4.0.13/vendor/bootstrap.min.js?ver=3.3.2'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var EasyAzonPro_Components_Popovers = {"ajaxUrl":"http:\/\/www.activistpost.com\/wp-admin\/admin-ajax.php","ajaxAction":"easyazon_get_popover_markup","loading":"Loading product data.","placement":"top","template":"<div class=\"popover easyazon-popover\"><div class=\"arrow\"><\/div><h3 class=\"popover-title\"><\/h3><div class=\"popover-content easyazon-popover-content\"><\/div><\/div>","timeout":"750"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='http://www.activistpost.com/wp-content/plugins/easyazon-pro-4.0.13/components/popovers/resources/popovers.js?ver=4.0.13'></script>
# <script type='text/javascript' src='http://www.activistpost.com/wp-includes/js/comment-reply.min.js?ver=4.7.3'></script>
# <script type='text/javascript' src='http://www.activistpost.com/wp-content/plugins/easy-social-share-buttons3/assets/js/easy-social-share-buttons.min.js?ver=4.1'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var boxzilla_options = {"testMode":"","boxes":[{"id":122340,"icon":"&times;","content":"<h3>Activist Post Daily Newsletter<\/h3>\n<p>&nbsp;<br \/>\n<span style=\"font-size: 16px;\">Get the latest articles from Activist Post delivered straight to your inbox every morning.<\/span><\/p>\n<p>&nbsp;<\/p>\n<p><span style=\"font-size: 16px;\">As an added bonus you&#8217;ll get access to special reports built exclusively for Activist Post subscribers.<\/span><\/p>\n<p>&nbsp;<\/p>\n<h4>Enter your email address below!<\/h4>\n<div style=\"float: left;\"><script type=\"text\/javascript\">(function() {\n\tif (!window.mc4wp) {\n\t\twindow.mc4wp = {\n\t\t\tlisteners: [],\n\t\t\tforms    : {\n\t\t\t\ton: function (event, callback) {\n\t\t\t\t\twindow.mc4wp.listeners.push({\n\t\t\t\t\t\tevent   : event,\n\t\t\t\t\t\tcallback: callback\n\t\t\t\t\t});\n\t\t\t\t}\n\t\t\t}\n\t\t}\n\t}\n})();\n<\/script><!-- MailChimp for WordPress v4.0.13 - https:\/\/wordpress.org\/plugins\/mailchimp-for-wp\/ --><form id=\"mc4wp-form-1\" class=\"mc4wp-form mc4wp-form-116586 mc4wp-form-theme mc4wp-form-theme-blue\" method=\"post\" data-id=\"116586\" data-name=\"Default sign-up form\" ><div class=\"mc4wp-form-fields\"><p>\r\n\t<label>Email address: <\/label>\r\n\t<input type=\"email\" id=\"mc4wp_email\" name=\"EMAIL\" placeholder=\"Your email address\" required \/>\r\n<\/p>\r\n\t<input type=\"submit\" value=\"Sign up\" \/><div style=\"display: none;\"><input type=\"text\" name=\"_mc4wp_honeypot\" value=\"\" tabindex=\"-1\" autocomplete=\"off\" \/><\/div><input type=\"hidden\" name=\"_mc4wp_timestamp\" value=\"1488932647\" \/><input type=\"hidden\" name=\"_mc4wp_form_id\" value=\"116586\" \/><input type=\"hidden\" name=\"_mc4wp_form_element_id\" value=\"mc4wp-form-1\" \/><\/div><div class=\"mc4wp-response\"><\/div><\/form><!-- \/ MailChimp for WordPress Plugin --><\/div>\n","css":{"width":750,"border_color":"#005a8c","border_width":5,"border_style":"solid","position":"center"},"trigger":{"method":"time_on_page","value":"3"},"animation":"slide","cookie":{"triggered":72,"dismissed":168},"rehide":false,"position":"center","minimumScreenWidth":800,"closable":true,"post":{"id":122340,"title":"AP Newsletter","slug":"ap-newsletter"}}]};
# /* ]]> */
# </script>
# <script type='text/javascript' src='http://www.activistpost.com/wp-content/plugins/boxzilla/assets/js/script.min.js?ver=3.1.9'></script>
# <script type='text/javascript' src='http://www.activistpost.com/wp-content/plugins/boxzilla-google-analytics/assets/js/tracking.min.js?ver=1.1.4'></script>
# <script type='text/javascript' src='http://www.activistpost.com/wp-includes/js/wp-embed.min.js?ver=4.7.3'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var embedVars = {"disqusConfig":{"platform":"wordpress@4.7.3","language":""},"disqusIdentifier":"148756 http:\/\/www.activistpost.com\/?p=148756","disqusShortname":"theactivistpost","disqusTitle":"Did the Trump\/Johnson Effect Destroy Libertarianism?","disqusUrl":"http:\/\/www.activistpost.com\/2017\/02\/trumpjohnson-effect-destroy-libertarianism.html","options":{"manualSync":false},"postId":"148756"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='http://www.activistpost.com/wp-content/plugins/disqus-comment-system/media/js/disqus.js?ver=4.7.3'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var countVars = {"disqusShortname":"theactivistpost"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='http://www.activistpost.com/wp-content/plugins/disqus-comment-system/media/js/count.js?ver=4.7.3'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var mc4wp_forms_config = [];
# /* ]]> */
# </script>
# <script type='text/javascript' src='http://www.activistpost.com/wp-content/plugins/mailchimp-for-wp/assets/js/forms-api.min.js?ver=4.0.13'></script>
# <!--[if lte IE 9]>
# <script type='text/javascript' src='http://www.activistpost.com/wp-content/plugins/mailchimp-for-wp/assets/js/third-party/placeholders.min.js?ver=4.0.13'></script>
# <![endif]-->
# <div class="essbasc-popup essbasc-popup-html" data-popup-width="400"><a href="#" class="essbasc-popup-close" onclick="essbasc_popup_close(); return false;"></a><div class="essbasc-popup-content"><div align="left"><b>Thank you for sharing.</b>
#   <br/><b>Follow us to receive the latest updates.</b></div>
# <br/>
# <div class="essb-like "><div class="essb-like-facebook essb-block"><div class="essb-native-skinned-button metro"><div class="essb-native-outsite metro essb-native-facebook"><div class="essb-native-text metro"><span class="essb_icon_facebook"></span><span class="essb-native-text-inner">Like Us On Facebook</span></div><div class="essb-native-click"><div style="display: inline-block; height: 24px; max-height: 24px; vertical-align: top;;"><div class="fb-follow" data-href="http://www.facebook.com/activistpost" data-layout="button" data-show-faces="false"></div></div></div></div></div></div><div class="essb-like-twitter-follow essb-block"><div class="essb-native-skinned-button metro"><div class="essb-native-outsite metro essb-native-twitter"><div class="essb-native-text metro"><span class="essb_icon_twitter"></span><span class="essb-native-text-inner">Follow Us On Twitter</span></div><div class="essb-native-click"><a href="https://twitter.com/ActivistPost" class="twitter-follow-button" data-show-count="false" data-lang="en" data-show-screen-name="false">Follow</a></div></div></div></div></div>
# <div class="g-ytsubscribe" data-channel="ActivistPost" data-layout="default" data-count="hidden"></div>
# <div align="left"><script type="text/javascript">(function() {
# 	if (!window.mc4wp) {
# 		window.mc4wp = {
# 			listeners: [],
# 			forms    : {
# 				on: function (event, callback) {
# 					window.mc4wp.listeners.push({
# 						event   : event,
# 						callback: callback
# 					});
# 				}
# 			}
# 		}
# 	}
# })();
# </script><!-- MailChimp for WordPress v4.0.13 - https://wordpress.org/plugins/mailchimp-for-wp/ --><form id="mc4wp-form-4" class="mc4wp-form mc4wp-form-116586 mc4wp-form-theme mc4wp-form-theme-blue" method="post" data-id="116586" data-name="Default sign-up form" ><div class="mc4wp-form-fields"><p>
# 	<label>Email address: </label>
# 	<input type="email" id="mc4wp_email" name="EMAIL" placeholder="Your email address" required />
# </p>
# 	<input type="submit" value="Sign up" /><div style="display: none;"><input type="text" name="_mc4wp_honeypot" value="" tabindex="-1" autocomplete="off" /></div><input type="hidden" name="_mc4wp_timestamp" value="1488932647" /><input type="hidden" name="_mc4wp_form_id" value="116586" /><input type="hidden" name="_mc4wp_form_element_id" value="mc4wp-form-4" /></div><div class="mc4wp-response"></div></form><!-- / MailChimp for WordPress Plugin --></div></div></div><div class="essbasc-popup-shadow" onclick="essbasc_popup_close();"></div><script type="text/javascript">var essbasc_cookie_live = 3;</script><div class="essb_mailform"><div class="essb_mailform_content"><p>Send this to friend</p><label class="essb_mailform_content_label">Your email</label><input type="text" id="essb_mailform_from" class="essb_mailform_content_input" placeholder="Your email"/><label class="essb_mailform_content_label">Recipient email</label><input type="text" id="essb_mailform_to" class="essb_mailform_content_input" placeholder="Recipient email"/><div class="essb_mailform_content_buttons"><button id="essb_mailform_btn_submit" class="essb_mailform_content_button" onclick="essb_mailform_send();">Send</button><button id="essb_mailform_btn_cancel" class="essb_mailform_content_button" onclick="essb_close_mailform(); return false;">Cancel</button></div><input type="hidden" id="essb_mail_salt" value="468393453"/><input type="hidden" id="essb_mail_instance" value=""/><input type="hidden" id="essb_mail_post" value=""/></div></div><div class="essb_mailform_shadow"></div><link rel="stylesheet" id="easy-social-share-buttons-popupasc"  href="http://www.activistpost.com/wp-content/plugins/easy-social-share-buttons3/assets/css/essb-after-share-close.min.css" type="text/css" media="all" /><link rel="stylesheet" id="essb-cct-style"  href="http://www.activistpost.com/wp-content/plugins/easy-social-share-buttons3/lib/modules/click-to-tweet/assets/css/styles.css" type="text/css" media="all" /><link rel="stylesheet" id="easy-social-share-buttons-subscribe"  href="http://www.activistpost.com/wp-content/plugins/easy-social-share-buttons3/assets/css/essb-subscribe.min.css" type="text/css" media="all" /><link rel="stylesheet" id="essb-social-like-shortcode-css"  href="http://www.activistpost.com/wp-content/plugins/easy-social-share-buttons3/assets/css/essb-social-like-buttons.css" type="text/css" media="all" /><div id="fb-root"></div>
# 	<script>(function(d, s, id) {
# 	var js, fjs = d.getElementsByTagName(s)[0];
# 	if (d.getElementById(id)) return;
# 	js = d.createElement(s); js.id = id;  js.async = true;
# 	js.src = "//connect.facebook.net/en_US/sdk.js#version=v2.6&xfbml=1"
# 	fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));</script><script>!function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0],p=/^http:/.test(d.location)?'http':'https';if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src=p+'://platform.twitter.com/widgets.js';fjs.parentNode.insertBefore(js,fjs);}}(document, 'script', 'twitter-wjs');</script><script type="text/javascript" src="http://www.activistpost.com/wp-content/plugins/easy-social-share-buttons3/assets/js/essb-after-share-close.min.js?ver=4.1"></script><script type="text/javascript" src="http://www.activistpost.com/wp-content/plugins/easy-social-share-buttons3/assets/js/essb-subscribe.min.js?ver=4.1"></script><script type="text/javascript">var essb_clicked_lovethis = false; var essb_love_you_message_thanks = "Thank you for loving this."; var essb_love_you_message_loved = "You already love this today."; var essb_lovethis = function(oInstance) { if (essb_clicked_lovethis) { alert(essb_love_you_message_loved); return; } var element = jQuery('.essb_'+oInstance); if (!element.length) { return; } var instance_post_id = jQuery(element).attr("data-essb-postid") || ""; var cookie_set = essb_get_lovecookie("essb_love_"+instance_post_id); if (cookie_set) { alert(essb_love_you_message_loved); return; } if (typeof(essb_settings) != "undefined") { jQuery.post(essb_settings.ajax_url, { 'action': 'essb_love_action', 'post_id': instance_post_id, 'service': 'love', 'nonce': essb_settings.essb3_nonce }, function (data) { if (data) { alert(essb_love_you_message_thanks); }},'json'); } essb_tracking_only('', 'love', oInstance, true); }; var essb_get_lovecookie = function(name) { var value = "; " + document.cookie; var parts = value.split("; " + name + "="); if (parts.length == 2) return parts.pop().split(";").shift(); };var essb_window = function(oUrl, oService, oInstance) { var element = jQuery('.essb_'+oInstance); var instance_post_id = jQuery(element).attr("data-essb-postid") || ""; var instance_position = jQuery(element).attr("data-essb-position") || ""; var wnd; var w = 800 ; var h = 500; if (oService == "twitter") { w = 500; h= 300; } var left = (screen.width/2)-(w/2); var top = (screen.height/2)-(h/2); if (oService == "twitter") { wnd = window.open( oUrl, "essb_share_window", "height=300,width=500,resizable=1,scrollbars=yes,top="+top+",left="+left ); } else { wnd = window.open( oUrl, "essb_share_window", "height=500,width=800,resizable=1,scrollbars=yes,top="+top+",left="+left ); } if (typeof(essb_settings) != "undefined") { if (essb_settings.essb3_stats) { if (typeof(essb_handle_stats) != "undefined") { essb_handle_stats(oService, instance_post_id, oInstance); } } if (essb_settings.essb3_ga) { essb_ga_tracking(oService, oUrl, instance_position); } } essb_self_postcount(oService, instance_post_id); if (typeof(essb_abtesting_logger) != "undefined") { essb_abtesting_logger(oService, instance_post_id, oInstance); } var pollTimer = window.setInterval(function() { if (wnd.closed !== false) { window.clearInterval(pollTimer); essb_smart_onclose_events(oService, instance_post_id); } }, 200); }; var essb_self_postcount = function(oService, oCountID) { if (typeof(essb_settings) != "undefined") { oCountID = String(oCountID); jQuery.post(essb_settings.ajax_url, { 'action': 'essb_self_postcount', 'post_id': oCountID, 'service': oService, 'nonce': essb_settings.essb3_nonce }, function (data) { if (data) { }},'json'); } }; var essb_smart_onclose_events = function(oService, oPostID) { if (oService == "subscribe" || oService == "comments") return; if (typeof (essbasc_popup_show) == 'function') { essbasc_popup_show(); } if (typeof essb_acs_code == 'function') { essb_acs_code(oService, oPostID); } if (typeof(after_share_easyoptin) != "undefined") { essb_toggle_subscribe(after_share_easyoptin); } }; var essb_tracking_only = function(oUrl, oService, oInstance, oAfterShare) { var element = jQuery('.essb_'+oInstance); if (oUrl == "") { oUrl = document.URL; } var instance_post_id = jQuery(element).attr("data-es ...
# </html>
# <!-- Performance optimized by W3 Total Cache. Learn more: https://www.w3-edge.com/products/
#
# Page Caching using disk: enhanced
# Fragment Caching 2/2 fragments using disk
#
#  Served from: activistpost.com @ 2017-03-07 18:24:07 by W3 Total Cache -->
