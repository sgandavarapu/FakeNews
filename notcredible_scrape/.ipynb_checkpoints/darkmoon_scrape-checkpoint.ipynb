# %%
import requests
import json
import os
from bs4 import BeautifulSoup
from datetime import datetime
import newspaper

# %%
source = 'darkmoon'

# %%
month = '02'
days = [str(i) for i in list(range(18,29))]

dates = []
for day in days:
    if len(day)<2:
        day = "0{}".format(day)
    dates.append("{0}-{1}".format(month, day))
    
month='03'
days = [str(i) for i in list(range(1,14))]

for day in days:
    if len(day)<2:
        day = "0{}".format(day)
    dates.append("{0}-{1}".format(month, day))

# %%
for date in dates:
    # Load HTML
    filepath = '/ebs_volume/data/notCredible/{0}/{1}.html'.format(source,date)
    try:
        with open(filepath) as f:
            soup = BeautifulSoup(f, 'lxml')

        # Pull out article links
        links = []
        i=0

        for main in soup.findAll('main', attrs={'class':'site-main'}):
            for article in main.findAll('article'):
                for time in article.findAll('time', attrs={'class':'entry-date published'}):
                    if date in time["datetime"]:
                        for header in article.findAll('h2'):
                            for link in header.findAll('a'):
                                links.append(link.get('href'))

        links = set(links)
        links = list(links)

        i=0
        for link in links:
            link = newspaper.Article(link)
            link.download()
            html = link.html
            link.parse()
            date_longform = '{0}-2017'.format(date)
            title = link.title.replace(' – Darkmoon','')

            article = {}
            article["html"] = html
            article["title"] = title
            article["url"] = link.url
            article["date"] = date_longform
            article["source"] = source
            article["text"] = link.text
            article["images"] = list(link.images)
            article["videos"] = link.movies

            outfile = '/ebs_volume/data/notCredible/{0}/articles/{1}/article{2}.txt'.format(source,date,i)
            os.makedirs(os.path.dirname(outfile), exist_ok=True)
            i+=1

            with open(outfile, 'w') as f:
                json.dump(article, f)
                
    except FileNotFoundError:
        print("File not found")
# Out:
# File not found
# File not found
# File not found

# %%
# Test that articles saved correctly
with open('/mnt/c/Users/Brennan/Dropbox/MIDS/w210-capstone/data/notCredible/darkmoon/articles/02-20/article0_02-20.txt') as json_data:
    d = json.load(json_data)
    
print(d["title"])
print()
print(d["source"])
print()
print(d["url"])
print()
print(d["date"])
print()
print(d["text"])
print()
print(d["images"])
print()
print(d["videos"])
print()
print(d["html"])
# Out:
# Trump Presidency Predicted To End Very Soon
#
# darkmoon
#
# https://www.darkmoon.me/2017/trump-presidency-predicted-to-end-very-soon/
#
# 02-20-2017
#
# Trump’s term will last less than 200 days—the second shortest ever. He will be replaced by Vice President Mike Pence.
#
# By Ronald L. Feinman
#
# PENCE IS PREDICTED TO OUST TRUMP ANY TIME SOON
#
#
#
# The news of the forced resignation of National Security Adviser Michael Flynn, due to the scandal that he, as a private citizen, spoke to the Russian ambassador in December after President Barack Obama issued sanctions on Russia for their aggressive behavior, has rocked the Donald Trump Presidency.
#
# ...
