# %%
import requests
import json
import os
from bs4 import BeautifulSoup
from datetime import datetime
import newspaper

# %%
source = 'infostormer'
month = '03'
days = [str(i) for i in list(range(1,10))]

dates = []
for day in days:
    dates.append("{0}-0{1}".format(month, day))

# %%
for date in dates:
    # Load HTML
    filepath = '/mnt/c/Users/Brennan/Dropbox/MIDS/w210-capstone/data/notCredible/{0}/{1}.html'.format(source,date)
    with open(filepath) as f:
        soup = BeautifulSoup(f, 'lxml')

    # Pull out article links
    links = []
    i=0

    for div in soup.findAll('div', attrs={"class":"magz-image"}):
        for span in div.findAll('span', attrs={"class":"magz-meta"}):
            pubdate = str(datetime.strptime(span.text.split('|')[0], "%B %d, %Y "))
            if date in pubdate:
                for link in div.findAll('a', attrs={"class":"standard-format-icon"}):
                    links.append(link.get('href'))

    links = set(links)
    links = list(links)
    
    for link in links:        
        link = newspaper.Article(link)
        link.download()
        html = link.html
        link.parse()
        date_longform = '{0}-2017'.format(date)
        title = link.title.replace('Infostormer.Com   |  ', '')
        
        article = {}
        article["html"] = html
        article["title"] = title
        article["url"] = link.url
        article["date"] = date_longform
        article["source"] = source
        article["text"] = link.text
        article["images"] = list(link.images)
        article["videos"] = link.movies

        outfile = '/mnt/c/Users/Brennan/Dropbox/MIDS/w210-capstone/data/notCredible/{0}/articles/{2}/article{1}_{2}.txt'.format(source,i,date)
        os.makedirs(os.path.dirname(outfile), exist_ok=True)
        i+=1

        with open(outfile, 'w') as f:
            json.dump(article, f)

# %%
# Test that articles saved correctly
with open('/mnt/c/Users/Brennan/Dropbox/MIDS/w210-capstone/data/notCredible/infostormer/articles/02-18/article0_02-18.txt') as json_data:
    d = json.load(json_data)
    
print(d["title"])
print()
print(d["source"])
print()
print(d["url"])
print()
print(d["date"])
print()
print(d["text"])
print()
print(d["images"])
print()
print(d["videos"])
print()
print(d["html"])
# Out:
# LOL: The Great Rape Riots Of 2017 Spread Across France, Police Unable To Contain Violence
#
# infostormer
#
# http://www.infostormer.com/lol-the-great-rape-riots-of-2017-spread-across-france-police-unable-to-contain/
#
# 02-18-2017
#
# To all police officers:
#
# Please take into the future the knowledge that if you shove a baton up a Black man’s ass, you’ll have thousands of Arabs and Negroes riot in the streets of your nation’s largest cities.
#
# It’s almost certain (really a Law of Nature if you want to make things technical), and things can get really dicey and out of hand once the fun begins.
#
# From Daily Express:
#
# The ongoing trouble in Paris which has led to riots in some parts of the capital is spreading across France as vigilantes stage running battles with police in protest of the rape of a young black man.
#
# And law enforcement say two weeks of civil unrest has now led to frenzied clashes in 20 districts.
#
# ...
