# %%
from bs4 import BeautifulSoup
from datetime import datetime
import newspaper
import requests
import json
import os

##pull html
#url = "http://itmakessenseblog.com/"
#content = urllib.request.urlopen(url).read()
#soup = BeautifulSoup(content)
#print(soup.prettify())

#reading html flat files 
source = 'rickwells'
month = '02'
days = [str(i) for i in list(range(18,28))]

dates = []
for day in days:
    dates.append("{0}-{1}".format(month, day))
    
links = []   
for date in dates:
    filepath = 'data/notCredible/{0}/{1}.html'.format(source,date)
    with open(filepath) as f:
        soup = BeautifulSoup(f, 'lxml')
        
    # Pull out article links

    i=0
    
    for html_link in soup.find_all('a', {'rel': 'bookmark'}):
        url = html_link.get('href')
        if url not in links:
            links.append(url)

for link in links:   
    try:
        link = newspaper.Article(link)
        link.download()
        html = link.html
        link.parse()
        date_longform = ''

        article = {}
        article["html"] = html
        article["title"] = link.title
        article["url"] = link.url
        article["date"] = date_longform
        article["source"] = source
        article["text"] = link.text
        article["images"] = list(link.images)
        article["videos"] = link.movies

        outfile = 'data/notCredible/{0}/articles/article{1}.txt'.format(source,i)
        os.makedirs(os.path.dirname(outfile), exist_ok=True)
        i+=1

        with open(outfile, 'w') as f:
            json.dump(article, f)
    except:
        pass

# %%
#Scrape data for March
month = '03'
days = [str(i) for i in list(range(1,8))]

dates = []
for day in days:
    dates.append("{0}-{0:0>2}".format(month, day))
    
 

for date in dates:
    filepath = 'data/notCredible/{0}/{1}.html'.format(source,date)
    with open(filepath) as f:
        soup = BeautifulSoup(f, 'lxml')
        
    # Pull out article links

    i=81
    
    for html_link in soup.find_all('a', {'rel': 'bookmark'}):
        url = html_link.get('href')
        if url not in links:
            links.append(url)

for link in links:   
    try:
        link = newspaper.Article(link)
        link.download()
        html = link.html
        link.parse()
        date_longform = ''


        article = {}
        article["html"] = html
        article["title"] = link.title
        article["url"] = link.url
        article["date"] = date_longform
        article["source"] = source
        article["text"] = link.text
        article["images"] = list(link.images)
        article["videos"] = link.movies

        outfile = 'data/notCredible/{0}/articles/article{1}.txt'.format(source,i)
        os.makedirs(os.path.dirname(outfile), exist_ok=True)
        i+=1

        with open(outfile, 'w') as f:
            json.dump(article, f)
    except:
        pass

# %%
# Test that articles saved correctly
with open('data/notCredible/rickwells/articles/article12.txt') as json_data:
    d = json.load(json_data)
    
print(d["title"])
print()
print(d["source"])
print()
print(d["url"])
print()
print(d["date"])
print()
print(d["text"])
print()
print(d["images"])
print()
print(d["videos"])
print()
print(d["html"])
# Out:
# Obama, Soros Behind Disruption, Agitating, Intimidation at GOP TownHalls
#
# rickwells
#
# http://rickwells.us/obama-soros-public-enemies-attacking-agitating-intimidating-gop-town-halls/
#
#
#
# Share With Your Friends On Facebook, Twitter, Everywhere
#
#
#
#
#
#
#
#
#
#
#
# An Obama/Soros agitator group is building its forces within America with the goal of overturning the will of the people and imposing their communist ideology. This is presently manifesting itself in a variety to Democrat efforts from obstruction to chaos in the streets. It’s only going to get worse as Hussein Obama shifts from foreign usurper squatting in our White House to full-blown foreign communist agitator unleashing hordes of his thugs onto the streets and citizens of the United States.
#
#
# []
#
# <!DOCTYPE html>
# <html class="no-js mh-large mh-one-sb wt-layout3" lang="en-US" prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="UTF-8">
# <title>Obama, Soros Behind Disruption, Agitating, Intimidation at GOP TownHalls</title>
# <script type="text/javascript">function heateorSssLoadEvent(e) {var t=window.onload;if (typeof window.onload!="function") {window.onload=e}else{window.onload=function() {t();e()}}};	var heateorSssSharingAjaxUrl = 'http://rickwells.us/wp-admin/admin-ajax.php', heateorSssCloseIconPath = 'http://rickwells.us/wp-content/plugins/sassy-social-share/public/../images/close.png', heateorSssPluginIconPath = 'http://rickwells.us/wp-content/plugins/sassy-social-share/public/../images/logo.png', heateorSssHorizontalSharingCountEnable = 1, heateorSssVerticalSharingCountEnable = 0, heateorSssSharingOffset = 0;var heateorSssReduceHorizontalSvgWidth = true;var heateorSssUrlCountFetched = [], heateorSssSharesText = 'Shares', heateorSssShareText = 'Share';function heateorSssPopup(e) {window.open(e,"popUpWindow","height=400,width=600,left=400,top=100,resizable=yes,scrollbars=yes,toolbar=yes,menubar=no,location=no,directories=no,status=yes")}</script>			<style type="text/css">
# 					.heateor_sss_horizontal_sharing .heateorSssSharing{
# 							color: #fff;
# 						border-width: 1px;
# 			border-style: solid;
# 			border-color: transparent;
# 		}
# 				.heateor_sss_horizontal_sharing .heateorSssTCBackground{
# 			color:#666;
# 		}
# 				.heateor_sss_horizontal_sharing .heateorSssSharing:hover{
# 						border-color: transparent;
# 		}
# 		.heateor_sss_vertical_sharing .heateorSssSharing{
# 							color: #fff;
# 						border-width: 0px;
# 			border-style: solid;
# 			border-color: transparent;
# 		}
# 				.heateor_sss_vertical_sharing .heateorSssTCBackground{
# 			color:#666;
# 		}
# 				.heateor_sss_vertical_sharing .heateorSssSharing:hover{
# 						border-color: transparent;
# 		}
# 						div.heateor_sss_horizontal_sharing .heateorSssSharingSvg{width:50%;margin:auto;}div.heateor_sss_horizontal_sharing .heateor_sss_square_count{float:left;width:50%;line-height:35px;}
# 				@media screen and (max-width:788px) {.heateor_sss_vertical_sharing{display:none!important}}@media screen and (max-width:788px) {.heateor_sss_bottom_sharing{left:5px!important;right:auto!important;display:block!important;width: auto!important;bottom: -10px!important;top: auto!important;}.heateor_sss_bottom_sharing .heateor_sss_square_count{line-height: inherit;}.heateor_sss_bottom_sharing .heateorSssSharingArrow{display:none;}.heateor_sss_bottom_sharing .heateorSssTCBackground{margin-right: 1.1em !important}}			</style>
# 			<!-- Jetpack Site Verification Tags -->
# <meta name="msvalidate.01" content="30F71C38DF71C83780C0EF4B2B86446A" />
# <link rel="stylesheet" href="http://fonts.googleapis.com/css?family=Lato|Monda">
# <!--[if lt IE 9]>
# <script src="http://css3-mediaqueries-js.googlecode.com/svn/trunk/css3-mediaqueries.js"></script>
# <![endif]-->
# <meta name="viewport" content="width=device-width; initial-scale=1.0">
# <link rel="pingback" href="http://rickwells.us/xmlrpc.php"/>
#
# <!-- This site is optimized with the Yoast SEO plugin v4.0.2 - https://yoast.com/wordpress/plugins/seo/ -->
# <meta name="description" content="Obama is an Alinsky agitator and communist with Soros money behind him and a huge ego. He&#039;s doing just what we expect, undermining the USA, wreaking chaos"/>
# <meta name="robots" content="noodp"/>
# <link rel="canonical" href="http://rickwells.us/obama-soros-public-enemies-attacking-agitating-intimidating-gop-town-halls/" />
# <meta property="og:locale" content="en_US" />
# <meta property="og:type" content="article" />
# <meta property="og:title" content="Obama, Soros Behind Disruption, Agitating, Intimidation at GOP TownHalls" />
# <meta property="og:description" content="Obama is an Alinsky agitator and communist with Soros money behind him and a huge ego. He&#039;s doing just what we expect, undermining the USA, wreaking chaos" />
# <meta property="og:url" content="http://rickwells.us/obama-soros-public-enemies-attacking-agitating-intimidating-gop-town-halls/" />
# <meta property="og:site_name" content="RickWells.US" />
# <meta property="article:publisher" content="https://www.facebook.com/pages/Rick-Wells/1405080846374047" />
# <meta property="article:section" content="Communism" />
# <meta property="article:published_time" content="2017-02-20T08:16:00+08:00" />
# <meta property="og:image" content="http://rickwells.us/wp-content/uploads/2017/02/790-obama-soros-1200.png" />
# <meta property="og:image:width" content="1200" />
# <meta property="og:image:height" content="628" />
# <!-- / Yoast SEO plugin. -->
#
# <link rel='dns-prefetch' href='//s0.wp.com' />
# <link rel='dns-prefetch' href='//s.gravatar.com' />
# <link rel='dns-prefetch' href='//code.jquery.com' />
# <link rel='dns-prefetch' href='//s.w.org' />
# <link rel="alternate" type="application/rss+xml" title="RickWells.US &raquo; Feed" href="http://rickwells.us/feed/" />
# <link rel="alternate" type="application/rss+xml" title="RickWells.US &raquo; Comments Feed" href="http://rickwells.us/comments/feed/" />
# <link rel="alternate" type="application/rss+xml" title="RickWells.US &raquo; Obama, Soros Public Enemies Attacking, Agitating, Intimidating At GOP Town Halls Comments Feed" href="http://rickwells.us/obama-soros-public-enemies-attacking-agitating-intimidating-gop-town-halls/feed/" />
# 		<script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/2.2.1\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/2.2.1\/svg\/","svgExt":".svg","source":{"concatemoji":"http:\/\/rickwells.us\/wp-includes\/js\/wp-emoji-release.min.js?ver=4.7.3"}};
# 			!function(a,b,c){function d(a){var b,c,d,e,f=String.fromCharCode;if(!k||!k.fillText)return!1;switch(k.clearRect(0,0,j.width,j.height),k.textBaseline="top",k.font="600 32px Arial",a){case"flag":return k.fillText(f(55356,56826,55356,56819),0,0),!(j.toDataURL().length<3e3)&&(k.clearRect(0,0,j.width,j.height),k.fillText(f(55356,57331,65039,8205,55356,57096),0,0),b=j.toDataURL(),k.clearRect(0,0,j.width,j.height),k.fillText(f(55356,57331,55356,57096),0,0),c=j.toDataURL(),b!==c);case"emoji4":return k.fillText(f(55357,56425,55356,57341,8205,55357,56507),0,0),d=j.toDataURL(),k.clearRect(0,0,j.width,j.height),k.fillText(f(55357,56425,55356,57341,55357,56507),0,0),e=j.toDataURL(),d!==e}return!1}function e(a){var c=b.createElement("script");c.src=a,c.defer=c.type="text/javascript",b.getElementsByTagName("head")[0].appendChild(c)}var f,g,h,i,j=b.createElement("canvas"),k=j.getContext&&j.getContext("2d");for(i=Array("flag","emoji4"),c.supports={everything:!0,everythingExceptFlag:!0},h=0;h<i.length;h++)c.supports[i[h]]=d(i[h]),c.supports.everything=c.supports.everything&&c.supports[i[h]],"flag"!==i[h]&&(c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&c.supports[i[h]]);c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&!c.supports.flag,c.DOMReady=!1,c.readyCallback=function(){c.DOMReady=!0},c.supports.everything||(g=function(){c.readyCallback()},b.addEventListener?(b.addEventListener("DOMContentLoaded",g,!1),a.addEventListener("load",g,!1)):(a.attachEvent("onload",g),b.attachEvent("onreadystatechange",function(){"complete"===b.readyState&&c.readyCallback()})),f=c.source||{},f.concatemoji?e(f.concatemoji):f.wpemoji&&f.twemoji&&(e(f.twemoji),e(f.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# 		<style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link rel='stylesheet' id='mh-style-css'  href='http://rickwells.us/wp-content/themes/mh_magazine/style.css?ver=2.0.2' type='text/css' media='all' />
# <link rel='stylesheet' id='heateor_sss_frontend_css-css'  href='http://rickwells.us/wp-content/plugins/sassy-social-share/public/css/sassy-social-share-public.css?ver=2.5.5' type='text/css' media='all' />
# <link rel='stylesheet' id='heateor_sss_sharing_default_svg-css'  href='http://rickwells.us/wp-content/plugins/sassy-social-share/public/../admin/css/sassy-social-share-svg.css?ver=2.5.5' type='text/css' media='all' />
# <link rel='stylesheet' id='jetpack_css-css'  href='http://rickwells.us/wp-content/plugins/jetpack/css/jetpack.css?ver=4.4.2' type='text/css' media='all' />
# <script type='text/javascript' src='http://rickwells.us/wp-includes/js/jquery/jquery.js?ver=1.12.4'></script>
# <script type='text/javascript' src='http://rickwells.us/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var related_posts_js_options = {"post_heading":"h4"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='http://rickwells.us/wp-content/plugins/jetpack/modules/related-posts/related-posts.js?ver=20150408'></script>
# <script type='text/javascript' src='http://code.jquery.com/jquery-migrate-1.2.1.min.js?ver=4.7.3'></script>
# <script type='text/javascript' src='http://rickwells.us/wp-content/themes/mh_magazine/js/scripts.js?ver=4.7.3'></script>
# <link rel='https://api.w.org/' href='http://rickwells.us/wp-json/' />
# <link rel="EditURI" type="application/rsd+xml" title="RSD" href="http://rickwells.us/xmlrpc.php?rsd" />
# <link rel="wlwmanifest" type="application/wlwmanifest+xml" href="http://rickwells.us/wp-includes/wlwmanifest.xml" />
# <meta name="generator" content="WordPress 4.7.3" />
# <link rel='shortlink' href='http://wp.me/p4yNKg-aZI' />
# <link rel="alternate" type="application/json+oembed" href="http://rickwells.us/wp-json/oembed/1.0/embed?url=http%3A%2F%2Frickwells.us%2Fobama-soros-public-enemies-attacking-agitating-intimidating-gop-town-halls%2F" />
# <link rel="alternate" type="text/xml+oembed" href="http://rickwells.us/wp-json/oembed/1.0/embed?url=http%3A%2F%2Frickwells.us%2Fobama-soros-public-enemies-attacking-agitating-intimidating-gop-town-halls%2F&#038;format=xml" />
# <script type='text/javascript'>
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# (function() {
# var gads = document.createElement('script');
# gads.async = true;
# gads.type = 'text/javascript';
# var useSSL = 'https:' == document.location.protocol;
# gads.src = (useSSL ? 'https:' : 'http:') +
# '//www.googletagservices.com/tag/js/gpt.js';
# var node = document.getElementsByTagName('script')[0];
# node.parentNode.insertBefore(gads, node);
# })();
# </script>
#
# <script type='text/javascript'>
# googletag.cmd.push(function() {
# googletag.defineSlot('/127561266/Constitution_Rising_Top_Main_Page', [[200, 200], [234, 60], [240, 400], [250, 250], [300, 250]], 'div-gpt-ad-1424605800303-0').addService(googletag.pubads());
# googletag.pubads().enableSingleRequest();
# googletag.enableServices();
# });
# </script><script type='text/javascript'>
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# (function() {
# var gads = document.createElement('script');
# gads.async = true;
# gads.type = 'text/javascript';
# var useSSL = 'https:' == document.location.protocol;
# gads.src = (useSSL ? 'https:' : 'http:') +
# '//www.googletagservices.com/tag/js/gpt.js';
# var node = document.getElementsByTagName('script')[0];
# node.parentNode.insertBefore(gads, node);
# })();
# </script>
#
# <script type='text/javascript'>
# googletag.cmd.push(function() {
# googletag.defineSlot('/127561266/Constitution_Rising_MR_300x250', [300, 250], 'div-gpt-ad-1424608423273-0').addService(googletag.pubads());
# googletag.pubads().enableSingleRequest();
# googletag.enableServices();
# });
# </script><script type='text/javascript'>
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# (function() {
# var gads = document.createElement('script');
# gads.async = true;
# gads.type = 'text/javascript';
# var useSSL = 'https:' == document.location.protocol;
# gads.src = (useSSL ? 'https:' : 'http:') +
# '//www.googletagservices.com/tag/js/gpt.js';
# var node = document.getElementsByTagName('script')[0];
# node.parentNode.insertBefore(gads, node);
# })();
# </script>
#
# <script type='text/javascript'>
# googletag.cmd.push(function() {
# googletag.defineSlot('/127561266/Constitution_Rising_MR_300x250', [300, 250], 'div-gpt-ad-1424609073647-0').addService(googletag.pubads());
# googletag.pubads().enableSingleRequest();
# googletag.enableServices();
# });
# </script><script type='text/javascript'>
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# (function() {
# var gads = document.createElement('script');
# gads.async = true;
# gads.type = 'text/javascript';
# var useSSL = 'https:' == document.location.protocol;
# gads.src = (useSSL ? 'https:' : 'http:') +
# '//www.googletagservices.com/tag/js/gpt.js';
# var node = document.getElementsByTagName('script')[0];
# node.parentNode.insertBefore(gads, node);
# })();
# </script>
#
# <script type='text/javascript'>
# googletag.cmd.push(function() {
# googletag.defineSlot('/127561266/con_ris_300x250', [300, 250], 'div-gpt-ad-1424689883692-0').addService(googletag.pubads());
# googletag.pubads().enableSingleRequest();
# googletag.enableServices();
# });
# </script><script type='text/javascript'>
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# (function() {
# var gads = document.createElement('script');
# gads.async = true;
# gads.type = 'text/javascript';
# var useSSL = 'https:' == document.location.protocol;
# gads.src = (useSSL ? 'https:' : 'http:') +
# '//www.googletagservices.com/tag/js/gpt.js';
# var node = document.getElementsByTagName('script')[0];
# node.parentNode.insertBefore(gads, node);
# })();
# </script>
#
# <script type='text/javascript'>
# googletag.cmd.push(function() {
# googletag.defineSlot('/127561266/con_ris_300x250', [300, 250], 'div-gpt-ad-1424690233020-0').addService(googletag.pubads());
# googletag.pubads().enableSingleRequest();
# googletag.enableServices();
# });
# </script><script type='text/javascript'>
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# (function() {
# var gads = document.createElement('script');
# gads.async = true;
# gads.type = 'text/javascript';
# var useSSL = 'https:' == document.location.protocol;
# gads.src = (useSSL ? 'https:' : 'http:') +
# '//www.googletagservices.com/tag/js/gpt.js';
# var node = document.getElementsByTagName('script')[0];
# node.parentNode.insertBefore(gads, node);
# })();
# </script>
#
# <script type='text/javascript'>
# googletag.cmd.push(function() {
# googletag.defineSlot('/127561266/con_ris_300x250', [300, 250], 'div-gpt-ad-1424690653706-0').addService(googletag.pubads());
# googletag.pubads().enableSingleRequest();
# googletag.enableServices();
# });
# </script><script type='text/javascript'>
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# (function() {
# var gads = document.createElement('script');
# gads.async = true;
# gads.type = 'text/javascript';
# var useSSL = 'https:' == document.location.protocol;
# gads.src = (useSSL ? 'https:' : 'http:') +
# '//www.googletagservices.com/tag/js/gpt.js';
# var node = document.getElementsByTagName('script')[0];
# node.parentNode.insertBefore(gads, node);
# })();
# </script>
#
# <script type='text/javascript'>
# googletag.cmd.push(function() {
# googletag.defineSlot('/127561266/Constitution_Rising_Top_Main_Page', [[250, 250], [300, 250]], 'div-gpt-ad-1424857847232-0').addService(googletag.pubads());
# googletag.pubads().enableSingleRequest();
# googletag.enableServices();
# });
# </script><script type='text/javascript'>
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# (function() {
# var gads = document.createElement('script');
# gads.async = true;
# gads.type = 'text/javascript';
# var useSSL = 'https:' == document.location.protocol;
# gads.src = (useSSL ? 'https:' : 'http:') +
# '//www.googletagservices.com/tag/js/gpt.js';
# var node = document.getElementsByTagName('script')[0];
# node.parentNode.insertBefore(gads, node);
# })();
# </script>
#
# <script type='text/javascript'>
# googletag.cmd.push(function() {
# googletag.defineSlot('/127561266/Constitution_Rising_Top_Main_Page', [[250, 250], [300, 250]], 'div-gpt-ad-1424858161719-0').addService(googletag.pubads());
# googletag.pubads().enableSingleRequest();
# googletag.enableServices();
# });
# </script><script type='text/javascript'>
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# (function() {
# var gads = document.createElement('script');
# gads.async = true;
# gads.type = 'text/javascript';
# var useSSL = 'https:' == document.location.protocol;
# gads.src = (useSSL ? 'https:' : 'http:') +
# '//www.googletagservices.com/tag/js/gpt.js';
# var node = document.getElementsByTagName('script')[0];
# node.parentNode.insertBefore(gads, node);
# })();
# </script>
#
# <script type='text/javascript'>
# googletag.cmd.push(function() {
# googletag.defineSlot('/127561266/Constitution_Rising_Top_Main_Page', [[250, 250], [300, 250]], 'div-gpt-ad-1424858452203-0').addService(googletag.pubads());
# googletag.pubads().enableSingleRequest();
# googletag.enableServices();
# });
# </script><script type='text/javascript'>
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# (function() {
# var gads = document.createElement('script');
# gads.async = true;
# gads.type = 'text/javascript';
# var useSSL = 'https:' == document.location.protocol;
# gads.src = (useSSL ? 'https:' : 'http:') +
# '//www.googletagservices.com/tag/js/gpt.js';
# var node = document.getElementsByTagName('script')[0];
# node.parentNode.insertBefore(gads, node);
# })();
# </script>
#
# <script type='text/javascript'>
# googletag.cmd.push(function() {
# googletag.defineSlot('/127561266/Constitution_Rising_Top_Main_Page', [[250, 250], [300, 250]], 'div-gpt-ad-1424858658057-0').addService(googletag.pubads());
# googletag.pubads().enableSingleRequest();
# googletag.enableServices();
# });
# </script><script type='text/javascript'>
#   (function() {
#     var useSSL = 'https:' == document.location.protocol;
#     var src = (useSSL ? 'https:' : 'http:') +
#         '//www.googletagservices.com/tag/js/gpt.js';
#     document.write('<scr' + 'ipt src="' + src + '"></scr' + 'ipt>');
#   })();
# </script>
#
# <script type='text/javascript'>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/127561266/Constitution_Rising_MR_300x250', [300, 250], 'div-gpt-ad-1436357816748-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.pubads().enableSyncRendering();
#     googletag.enableServices();
#   });
# </script><script type='text/javascript'>
#   (function() {
#     var useSSL = 'https:' == document.location.protocol;
#     var src = (useSSL ? 'https:' : 'http:') +
#         '//www.googletagservices.com/tag/js/gpt.js';
#     document.write('<scr' + 'ipt src="' + src + '"></scr' + 'ipt>');
#   })();
# </script>
#
# <script type='text/javascript'>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/127561266/Constitution_Rising_MR_300x250', [300, 250], 'div-gpt-ad-1436358222838-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.pubads().enableSyncRendering();
#     googletag.enableServices();
#   });
# </script><script type='text/javascript'>
#   (function() {
#     var useSSL = 'https:' == document.location.protocol;
#     var src = (useSSL ? 'https:' : 'http:') +
#         '//www.googletagservices.com/tag/js/gpt.js';
#     document.write('<scr' + 'ipt src="' + src + '"></scr' + 'ipt>');
#   })();
# </script>
#
# <script type='text/javascript'>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/127561266/Constitution_Rising_MR_300x250', [300, 250], 'div-gpt-ad-1436358439635-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.pubads().enableSyncRendering();
#     googletag.enableServices();
#   });
# </script><script type='text/javascript'>
#   (function() {
#     var useSSL = 'https:' == document.location.protocol;
#     var src = (useSSL ? 'https:' : 'http:') +
#         '//www.googletagservices.com/tag/js/gpt.js';
#     document.write('<scr' + 'ipt src="' + src + '"></scr' + 'ipt>');
#   })();
# </script>
#
# <script type='text/javascript'>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/127561266/Constitution_Rising_Top_Main_Page', [[250, 250], [300, 250]], 'div-gpt-ad-1436358814335-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.pubads().enableSyncRendering();
#     googletag.enableServices();
#   });
# </script><script type='text/javascript'>
#   (function() {
#     var useSSL = 'https:' == document.location.protocol;
#     var src = (useSSL ? 'https:' : 'http:') +
#         '//www.googletagservices.com/tag/js/gpt.js';
#     document.write('<scr' + 'ipt src="' + src + '"></scr' + 'ipt>');
#   })();
# </script>
#
# <script type='text/javascript'>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/127561266/third300x250', [300, 250], 'div-gpt-ad-1438077810346-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.pubads().enableSyncRendering();
#     googletag.enableServices();
#   });
# </script><script type='text/javascript'>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#       '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   })();
# </script>
#
# <script type='text/javascript'>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/127561266/dcjan16size300250', [300, 250], 'div-gpt-ad-1453330291923-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script><script type='text/javascript'>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#       '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   })();
# </script>
#
# <script type='text/javascript'>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/127561266/feb7_2016sidebar250x250pos2', [250, 250], 'div-gpt-ad-1454841135047-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script><script type='text/javascript'>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#       '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   })();
# </script>
#
# <script type='text/javascript'>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/127561266/feb7_2016sidebar250x250pos2', [250, 250], 'div-gpt-ad-1454841135047-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script><script type='text/javascript'>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#       '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   })();
# </script>
#
# <script type='text/javascript'>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/127561266/feb7_2016sidebar250x250pos2', [250, 250], 'div-gpt-ad-1454842013101-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script><script type='text/javascript'>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#       '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   })();
# </script>
#
# <script type='text/javascript'>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/127561266/Con_Ris_300x600', [300, 600], 'div-gpt-ad-1454843059400-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script><script type='text/javascript'>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#       '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   })();
# </script>
#
# <script type='text/javascript'>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/127561266/feb7hp300x600pos2', [300, 600], 'div-gpt-ad-1454844921698-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script><script type='text/javascript'>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#       '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   })();
# </script>
#
# <script type='text/javascript'>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/127561266/FEB072016300x600pos1', [[250, 250], [300, 250], [300, 600]], 'div-gpt-ad-1454846426977-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script><script type='text/javascript'>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#       '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   })();
# </script>
#
# <script type='text/javascript'>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/127561266/FEB07300x600TWOpos1', [300, 600], 'div-gpt-ad-1454847043532-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script><script type='text/javascript'>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#       '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   })();
# </script>
#
# <script type='text/javascript'>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/127561266/FEB072016300x600pos1', [[300, 600], [250, 250], [300, 250]], 'div-gpt-ad-1454883852856-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script><script type='text/javascript'>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#       '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   })();
# </script>
#
# <script type='text/javascript'>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/127561266/FEB07300x600TWOpos1', [300, 600], 'div-gpt-ad-1455969026666-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script><script type='text/javascript'>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#       '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   })();
# </script>
#
# <script type='text/javascript'>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/127561266/con_ris_300x250', [300, 250], 'div-gpt-ad-1456531335147-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script><script type='text/javascript'>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#       '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   })();
# </script>
#
# <script type='text/javascript'>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/127561266/con_ris_300x250', [300, 250], 'div-gpt-ad-1456531572716-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script><script type='text/javascript'>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#       '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   })();
# </script>
#
# <script type='text/javascript'>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/127561266/con_ris_300x250', [300, 250], 'div-gpt-ad-1456531801652-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script><script type='text/javascript'>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#       '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   })();
# </script>
#
# <script type='text/javascript'>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/127561266/pos2FEB28300x600', [300, 600], 'div-gpt-ad-1456566213888-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script><script type='text/javascript'>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#       '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   })();
# </script>
#
# <script type='text/javascript'>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/127561266/pos2FEB28300x600', [300, 600], 'div-gpt-ad-1456566452853-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script><script type='text/javascript'>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#       '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   })();
# </script>
#
# <script type='text/javascript'>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/127561266/pos2FEB28300x600', [300, 600], 'div-gpt-ad-1456566665875-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script><script async='async' src='https://www.googletagservices.com/tag/js/gpt.js'></script>
# <script>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
# </script>
#
# <script>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/127561266/third300x250', [300, 250], 'div-gpt-ad-1472820858937-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script>
# <link rel='dns-prefetch' href='//v0.wordpress.com'>
# <link rel='dns-prefetch' href='//widgets.wp.com'>
# <link rel='dns-prefetch' href='//s0.wp.com'>
# <link rel='dns-prefetch' href='//0.gravatar.com'>
# <link rel='dns-prefetch' href='//1.gravatar.com'>
# <link rel='dns-prefetch' href='//2.gravatar.com'>
#     <style type="text/css">
#     	    		.entry { font-size: 16px; font-size: 1rem; }
#     	    				h1, h2, h3, h4, h5, h6 { font-family: "Monda", sans-serif; }
# 							body { font-family: "Lato", sans-serif; }
# 		    	    		.header-wrap { background: #ffffff }
#     	    	    		.wrapper { background: #ffffff }
#     	    	    		.main-nav,
#     		.header-nav .menu .menu-item:hover > .sub-menu,
#     		.main-nav .menu .menu-item:hover > .sub-menu,
#     		.footer-nav .menu-item:hover,
#     		.slide-caption,
#     		.spotlight,
#     		.carousel-layout1,
#     		footer,
#     		.loop-layout2 .meta, .loop-layout3 .meta, .loop-layout4 .meta,
# 			input[type=submit]:hover,
#     		#cancel-comment-reply-link:hover { background: #bc0505 }
#     	    	    		.ticker-title,
#     		.header-nav .menu-item:hover,
#     		.main-nav li:hover,
#     		.footer-nav,
#     		.footer-nav .menu .menu-item:hover > .sub-menu,
#     		.slider-layout2 .flex-control-paging li a.flex-active,
#     		.sl-caption,
#     		.subheading,
#     		.page-title-layout1,
#     		.wt-layout2 .widget-title,
#     		.wt-layout2 .footer-widget-title,
#     		.carousel-layout1 .caption,
#     		.loop-layout3 .loop-title,
#     		.page-numbers:hover,
#     		.current,
#     		.pagelink,
#     		a:hover .pagelink,
#     		input[type=submit],
#     		#cancel-comment-reply-link,
#     		.post-tags li:hover,
#     		.tagcloud a:hover,
#     		.sb-widget .tagcloud a:hover,
#     		.footer-widget .tagcloud a:hover { background: #010049; }
#     		.slide-caption,
#     		.mh-mobile .slide-caption,
#     		[id*='carousel-'],
#     		.wt-layout1 .widget-title,
#     		.wt-layout1 .footer-widget-title,
#     		.wt-layout3 .widget-title,
#     		.wt-layout3 .footer-widget-title,
#     		.author-box-layout1,
#     		.cat-desc,
# 			input[type=text]:hover,
# 			textarea:hover,
# 			.wpcf7-form input[type=email]:hover,
#     		blockquote { border-color: #010049; }
#     		a:hover,
#     		.entry a:hover,
#     		.slide-title:hover,
#     		.sl-title:hover,
#     		.carousel-layout2 .caption,
#     		.carousel-layout2 .carousel-item-title:hover,
#     		.related-title:hover,
#     		.dropcap { color: #010049; }
#     	    	    		.news-ticker,
#     		#searchform,
#     		.author-box,
#     		.cat-desc,
#     		.post-nav-wrap,
#     		#wp-calendar caption,
#     		.no-comments,
#     		#respond,
#     		.wpcf7-form { background: #f9c300; }
#     	    	    		body { color: #000000; }
#     	    	    		.logo-desc,
#     		.header-nav .menu-item:hover a,
#     		.header-nav .sub-menu a,
#     		.main-nav li a,
#     		.footer-nav .menu-item:hover a,
#     		.footer-nav .sub-menu a,
#     		.ticker-title,
#     		.subheading,
#     		.page-title,
#     		footer,
#     		.sl-title,
#     		.sl-caption,
#     		.slide-caption,
#     		.caption { color: #ffffff; }
#     	    	    		.meta, .breadcrumb { color: #bc0505; }
#     	    	    		.entry a { color: #000cf2; }
#     	    		</style>
#     <style type="text/css" id="custom-background-css">
# body.custom-background { background-color: #00041e; }
# </style>
# <link rel="icon" href="http://rickwells.us/wp-content/uploads/2015/08/con-ris-icon-512x2-rwo-55bf6084v1_site_icon-32x32.png" sizes="32x32" />
# <link rel="icon" href="http://rickwells.us/wp-content/uploads/2015/08/con-ris-icon-512x2-rwo-55bf6084v1_site_icon-256x256.png" sizes="192x192" />
# <link rel="apple-touch-icon-precomposed" href="http://rickwells.us/wp-content/uploads/2015/08/con-ris-icon-512x2-rwo-55bf6084v1_site_icon-256x256.png" />
# <meta name="msapplication-TileImage" content="http://rickwells.us/wp-content/uploads/2015/08/con-ris-icon-512x2-rwo-55bf6084v1_site_icon.png" />
# </head>
# <body id="mh-mobile" class="post-template-default single single-post postid-42266 single-format-standard custom-background">
# <aside class="header-widget">
# ...
# 											<p class="meta">March 13, 2017						</p>
# 									</div>
# 				<div class="mh-excerpt">Share With Your Friends On Facebook, <a href="http://rickwells.us/teammates-mccain-tapper-say-trump-must-release-obama-spying-evidence/" title="Teammates McCain, Tapper Say Trump Must Release Obama Spying Evidence">[More]</a></div>
# 			</li>        </ul></div><div class="sb-widget">			<div class="textwidget"><!-- /127561266/pos2FEB28300x600 -->
# <div id='div-gpt-ad-1456566452853-0' style='height:600px; width:300px;'>
# <script type='text/javascript'>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1456566452853-0'); });
# </script>
# </div></div>
# 		</div><div class="sb-widget">        <ul class="cp-widget clearfix"> 			<li class="cp-wrap cp-large clearfix">
# 									<div class="cp-thumb-xl"><a href="http://rickwells.us/surprise-dnc-deputy-ellison-lies-trump-russia-collusion-cnn-host-calls/" title="Surprise &#8211; DNC Deputy Ellison Lies About Trump Russia Collusion, CNN Host Calls It"><img width="300" height="225" src="http://rickwells.us/wp-content/uploads/2017/03/810-ellison-camerota-1200-300x225.png" class="attachment-cp_large size-cp_large wp-post-image" alt="ellison camerota" srcset="http://rickwells.us/wp-content/uploads/2017/03/810-ellison-camerota-1200-300x225.png 300w, http://rickwells.us/wp-content/uploads/2017/03/810-ellison-camerota-1200-174x131.png 174w, http://rickwells.us/wp-content/uploads/2017/03/810-ellison-camerota-1200-70x53.png 70w" sizes="(max-width: 300px) 100vw, 300px" /></a></div>
# 								<div class="cp-data">
# 					<h3 class="cp-xl-title"><a href="http://rickwells.us/surprise-dnc-deputy-ellison-lies-trump-russia-collusion-cnn-host-calls/" title="Surprise &#8211; DNC Deputy Ellison Lies About Trump Russia Collusion, CNN Host Calls It">Surprise &#8211; DNC Deputy Ellison Lies About Trump Russia Collusion, CNN Host Calls It</a></h3>
# 											<p class="meta">March 12, 2017						</p>
# 									</div>
# 	<option value='http://rickwells.us/2014/06/'> June 2014 &nbsp;(41)</option>
# 	<option value='http://rickwells.us/2014/05/'> May 2014 &nbsp;(14)</option>
#
# 		</select>
# 		</div><div class="sb-widget">			<div class="textwidget"><div id="NmWg3318" ></div><script type="text/javascript" src ='https://cdn.nmcdn.us/js/connectV3.js'></script><script type="text/javascript">  NM.init({WidgetID: 3318})</script></div>
# 		</div>	</aside>
#
# 	</div>
#     </div>
# <footer class="row clearfix">
# 		<div class="col-1-4 mq-footer">
# 		<div class="footer-widget footer-1">			<div class="textwidget"><script type="text/javascript">
# amzn_assoc_placement = "adunit0";
# amzn_assoc_search_bar = "true";
# amzn_assoc_tracking_id = "rickw-20";
# amzn_assoc_ad_mode = "manual";
# amzn_assoc_ad_type = "smart";
# amzn_assoc_marketplace = "amazon";
# amzn_assoc_region = "US";
# amzn_assoc_title = "My Amazon Picks";
# amzn_assoc_linkid = "3a35d9ff9b28edf461e3480cdc734057";
# amzn_assoc_asins = "0062369296,1455568872,1510713921,1510706798";
# </script>
# <script src="//z-na.amazon-adsystem.com/widgets/onejs?MarketPlace=US"></script></div>
# 		</div>	</div>
# 			<div class="col-1-4 mq-footer">
# 		<div class="footer-widget footer-2">			<div class="textwidget"><script type="text/javascript">
# amzn_assoc_placement = "adunit0";
# amzn_assoc_search_bar = "true";
# amzn_assoc_tracking_id = "rickw-20";
# amzn_assoc_ad_mode = "manual";
# amzn_assoc_ad_type = "smart";
# amzn_assoc_marketplace = "amazon";
# amzn_assoc_region = "US";
# amzn_assoc_title = "My Amazon Picks";
# amzn_assoc_linkid = "3a35d9ff9b28edf461e3480cdc734057";
# amzn_assoc_asins = "0930852435,148267789X,0970312598,1936488507";
# </script>
# <script src="//z-na.amazon-adsystem.com/widgets/onejs?MarketPlace=US"></script></div>
# 		</div>	</div>
# 			<div class="col-1-4 mq-footer">
# 		<div class="footer-widget footer-3">			<div class="textwidget"><script type="text/javascript">
# amzn_assoc_placement = "adunit0";
# amzn_assoc_search_bar = "true";
# amzn_assoc_tracking_id = "rickw-20";
# amzn_assoc_ad_mode = "manual";
# amzn_assoc_ad_type = "smart";
# amzn_assoc_marketplace = "amazon";
# amzn_assoc_region = "US";
# amzn_assoc_title = "My Amazon Picks";
# amzn_assoc_linkid = "3a35d9ff9b28edf461e3480cdc734057";
# amzn_assoc_asins = "0399594493,B01F45AJCO,B0110MZCKE,B01B3GC58Y";
# </script>
# <script src="//z-na.amazon-adsystem.com/widgets/onejs?MarketPlace=US"></script></div>
# 		</div>	</div>
# 			<div class="col-1-4 mq-footer">
# 		<div class="footer-widget footer-4">			<div class="textwidget"><script type="text/javascript">
# amzn_assoc_placement = "adunit0";
# amzn_assoc_search_bar = "true";
# amzn_assoc_tracking_id = "rickw-20";
# amzn_assoc_ad_mode = "manual";
# amzn_assoc_ad_type = "smart";
# amzn_assoc_marketplace = "amazon";
# amzn_assoc_region = "US";
# amzn_assoc_title = "My Amazon Picks";
# amzn_assoc_linkid = "3a35d9ff9b28edf461e3480cdc734057";
# amzn_assoc_asins = "B01FGKTDI8,B01IIKU9Y0,B01IURBY8G,091298645X";
# </script>
# <script src="//z-na.amazon-adsystem.com/widgets/onejs?MarketPlace=US"></script></div>
# 		</div>	</div>
# 	</footer>
# 	<nav class="footer-nav clearfix">
# 		<div class="menu-rickwells-consrising-container"><ul id="menu-rickwells-consrising-1" class="menu"><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-home menu-item-3384"><a href="http://rickwells.us/">Home</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3385"><a href="http://rickwells.us/about-us/">About Us</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3386"><a href="http://rickwells.us/contact-us/">Contact Info</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3388"><a href="http://rickwells.us/site-map/">Site Map</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3387"><a href="http://rickwells.us/privacy-policy/">Privacy Policy</a></li>
# </ul></div>	</nav>
# </div>
# <div class="copyright-wrap">
# 	<p class="copyright">Copyright &copy; 2017 | Theme by <a href="http://www.mhthemes.com/" title="Premium WordPress Themes">MH Themes</a></p>
# </div>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-83625266-1', 'auto');
#   ga('send', 'pageview');
#
# </script>
# 		<!-- Infolinks START -->
# 		<script type="text/javascript">
# 	   		var infolinks_plugin_version = "WP_3.1.9";
# 		</script>
# 		<script type="text/javascript" src="//resources.infolinks.com/js/infolinks_main.js?pid=2431460&wsid=0" ></script>
# 		<script type="text/javascript">
# 							jQuery(document).ready(function(){
# 							jQuery('.description').before('<span><!--INFOLINKS_OFF--></span>');jQuery('.description').after('<span><!--INFOLINKS_ON--></span>');jQuery('#headerimg').before('<span><!--INFOLINKS_OFF--></span>');jQuery('#headerimg').after('<span><!--INFOLINKS_ON--></span>');jQuery('h1').before('<span><!--INFOLINKS_OFF--></span>');jQuery('h1').after('<span><!--INFOLINKS_ON--></span>');jQuery('h1').before('<span><!--INFOLINKS_OFF--></span>');jQuery('h1').after('<span><!--INFOLINKS_ON--></span>');
# 								});
# 						</script>
# 		<!-- Infolinks END -->	<div style="display:none">
# 	<div class="grofile-hash-map-9a511624d3dd033fb6fddf26f33905af">
# 	</div>
# 	<div class="grofile-hash-map-2bcd581758550bbd151eb94058f6ee7f">
# 	</div>
# 	<div class="grofile-hash-map-272c9101d7f8624a9c94a54b4ff5d83e">
# 	</div>
# 	<div class="grofile-hash-map-20d89a1d9614f834fe37fdf1e5492616">
# 	</div>
# 	<div class="grofile-hash-map-f041de1c25b385a1973e4151943215d0">
# 	</div>
# 	</div>
# <div id='fb-root'></div><script>(function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = 'https://connect.facebook.net/en_US/all.js#xfbml=1'; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));</script>
# <script type='text/javascript' src='http://s0.wp.com/wp-content/js/devicepx-jetpack.js?ver=201711'></script>
# <script type='text/javascript' src='http://s.gravatar.com/js/gprofiles.js?ver=2017Maraa'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var WPGroHo = {"my_hash":""};
# /* ]]> */
# </script>
# <script type='text/javascript' src='http://rickwells.us/wp-content/plugins/jetpack/modules/wpgroho.js?ver=4.7.3'></script>
# <script type='text/javascript' src='http://rickwells.us/wp-includes/js/comment-reply.min.js?ver=4.7.3'></script>
# <script type='text/javascript' src='http://rickwells.us/wp-content/plugins/sassy-social-share/public/js/sassy-social-share-public.js?ver=2.5.5'></script>
# <script type='text/javascript' src='http://rickwells.us/wp-includes/js/wp-embed.min.js?ver=4.7.3'></script>
# <script type='text/javascript' src='http://stats.wp.com/e-201711.js' async defer></script>
# <script type='text/javascript'>
# 	_stq = window._stq || [];
# 	_stq.push([ 'view', {v:'ext',j:'1:4.4.2',blog:'67399720',post:'42266',tz:'8',srv:'rickwells.us'} ]);
# 	_stq.push([ 'clickTrackerInit', '67399720', '42266' ]);
# </script>
# </body>
# </html>
