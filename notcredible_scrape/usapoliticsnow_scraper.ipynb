# %%
from bs4 import BeautifulSoup
from datetime import datetime
import newspaper
import requests
import json
import os

##pull html
#url = "http://itmakessenseblog.com/"
#content = urllib.request.urlopen(url).read()
#soup = BeautifulSoup(content)
#print(soup.prettify())

#reading html flat files 
source = 'usapoliticsnow'
month = '02'
days = [str(i) for i in list(range(18,28))]

dates = []
for day in days:
    dates.append("{0}-{1}".format(month, day))
    
links = []   
for date in dates:
    filepath = 'data/notCredible/{0}/{1}.html'.format(source,date)
    with open(filepath) as f:
        soup = BeautifulSoup(f, 'lxml')
        
    # Pull out article links

    i=0
    
    for html_link in soup.find_all('a', {'rel': 'bookmark'}):
        url = html_link.get('href')
        if url not in links:
            links.append(url)

for link in links:        
    link = newspaper.Article(link)
    link.download()
    html = link.html
    link.parse()
    date_longform = ''
    title = link.title.replace(' - USA News Zone', '')

    article = {}
    article["html"] = html
    article["title"] = title
    article["url"] = link.url
    article["date"] = date_longform
    article["source"] = source
    article["text"] = link.text
    article["images"] = list(link.images)
    article["videos"] = link.movies

    outfile = 'data/notCredible/{0}/articles/article{1}.txt'.format(source,i)
    os.makedirs(os.path.dirname(outfile), exist_ok=True)
    i+=1

    with open(outfile, 'w') as f:
        json.dump(article, f)

# %%
#Scrape data for March
month = '03'
days = [str(i) for i in list(range(1,8))]

dates = []
for day in days:
    dates.append("{0}-{0:0>2}".format(month, day))
    
 

for date in dates:
    filepath = 'data/notCredible/{0}/{1}.html'.format(source,date)
    with open(filepath) as f:
        soup = BeautifulSoup(f, 'lxml')
        
    # Pull out article links

    i=85
    
    for html_link in soup.find_all('a', {'rel': 'bookmark'}):
        url = html_link.get('href')
        if url not in links:
            links.append(url)

for link in links:        
    link = newspaper.Article(link)
    link.download()
    html = link.html
    link.parse()
    date_longform = ''
    title = link.title.replace(' - USA News Zone', '')

    article = {}
    article["html"] = html
    article["title"] = title
    article["url"] = link.url
    article["date"] = date_longform
    article["source"] = source
    article["text"] = link.text
    article["images"] = list(link.images)
    article["videos"] = link.movies

    outfile = 'data/notCredible/{0}/articles/article{1}.txt'.format(source,i)
    os.makedirs(os.path.dirname(outfile), exist_ok=True)
    i+=1

    with open(outfile, 'w') as f:
        json.dump(article, f)

# %%
# Test that articles saved correctly
with open('data/notCredible/usapoliticsnow/articles/article16.txt') as json_data:
    d = json.load(json_data)
    
print(d["title"])
print()
print(d["source"])
print()
print(d["url"])
print()
print(d["date"])
print()
print(d["text"])
print()
print(d["images"])
print()
print(d["videos"])
print()
print(d["html"])
# Out:
# Jeff Sessions Tells Pelosi He ‘Will Not Back Down’ From DC Pedo Investigations
#
# usapoliticsnow
#
# http://usapoliticsnow.com/jeff-sessions-tells-pelosi-will-not-back-dc-pedo-investigations/
#
#
#
# A former CIA agent has warned that the deep state is working overtime to oust Attorney General Jeff Sessions from the White House because he is refusing to back down in his campaign to break up the sex trafficking and pedophile networks that control Washington D.C.
#
# According to Robert David Steele, Jeff Sessions is being set up as another “Russian fall guy“, just like General Flynn, to taint the Trump administration and push the president closer to impeachment.
#
# But most importantly, Steele warns, the deep state is determined to remove the most determined anti-pedophile and -corruption enforcer the office of Attorney General has seen in decades.
#
# The former CIA agent says that the Democrats push to remove Sessions from office, led by House Minority leader Nancy Pelosi, has “every chance of succeeding” because AG Sessions has made it clear he “will not back down” under any circumstances.
#
# Federal authorities have locked up more than 1,500 people on child trafficking and pedophilia charges since President Trump and AG Sessions assumed office, however the huge increase in numbers on recent years is being completely ignored by mainstream media.
#
# According to the FBI there were less than 400 sex trafficking-related arrests made in the entirety of 2014, proving that Trump are Sessions are serious about using “the “full force and weight” of the U.S. government to break up child sex trafficking rings and lock up sexual predators.
#
# In a hard-hitting video released late Feburary, Robert David Steele claimed that President Trump is our best chance to take down the deep state since President Kennedy.
#
# He also claimed that:
#
# * “White hat” intelligence community was able to stop Hillary from rigging the vote electronically like she did to Bernie
#
# * Former CIA head John Brennan committed treason by telling lies intended to overturn the Electoral College
#
# * John Brennan, highest paid agent of Saudi Arabia, should be under FBI investigation
#
# * Reince Priebus is an enabler and cover-upper of pedophilia — Former Speaker of the House Dennis Hastert is the tip of the iceberg
#
# * WikiLeaks is going to take down Priebus?
#
# * Pedophilia is an “elite privilege” — For the Democrats it’s an “acquired taste” — Podesta is a “pedo-light”
#
# * The Republicans and the elite in banking are the ones who have made pedophilia a “big league thing”
#
# * There are Saudi Arabian and Washington DC restaurants with basements where you can order children off of the menu
#
# * DC pedophilia is the Achilles heel, and Trump has figured that out
#
# * Flynn didn’t get fired because he called the Russians
#
# * Flynn got fired because he “had the arrogance to think” (sarcasm) that he could tell Mattis and Tillerson what to do
#
# * Flynn pissed off VP Pence
#
# * Flynn’s call that got him in trouble included a conversation about a list of high-level pedophiles inside the US, one of whom happens to be VP Mike Pence’s best friend
#
# * Flynn did not tell Pence about the list, or that his “best friend” was on it. Pence found out about this from the deep state (probably NSA taps)
#
# * The NSA has been spying on all of our politicians with impunity!
#
# * The CIA is leaking HIGHLY classified information as part of a political coup against Trump.
#
# ['http://usapoliticsnow.com/wp-content/uploads/2017/03/breaking-100x100.jpg', 'http://usapoliticsnow.com/wp-content/uploads/2017/03/sessions-dc-pedo-investigations-900x350.jpeg', 'http://usapoliticsnow.com/wp-content/uploads/2017/03/break-100x100.jpg', 'http://usapoliticsnow.com/wp-content/uploads/2017/03/17160853_10212395224461685_721879302_n-100x100.jpg', 'http://usapoliticsnow.com/wp-content/themes/viral/images/shadow.png', 'http://usapoliticsnow.com/wp-content/uploads/2017/03/Trump-Marines.001-100x100.jpeg', 'http://usapoliticsnow.com/wp-content/uploads/2016/04/cropped-cropped-usalojko-2-1.jpg', 'http://usapoliticsnow.com/wp-content/uploads/2017/03/Obama-white-house-parties-700x350-100x100.jpg']
#
# ['https://www.youtube.com/embed/JPYUWx0XyzU?feature=oembed']
#
# <!DOCTYPE html>
# <html lang="en-US" prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <link rel="profile" href="http://gmpg.org/xfn/11">
# <link rel="pingback" href="http://usapoliticsnow.com/xmlrpc.php">
#
# <title>Jeff Sessions Tells Pelosi He ‘Will Not Back Down’ From DC Pedo Investigations - USAPoliticsNow</title>
#
# <!-- Social Warfare v2.2.1 http://warfareplugins.com -->
# <style>@font-face {font-family: "sw-icon-font";src:url("http://usapoliticsnow.com/wp-content/plugins/social-warfare/fonts/sw-icon-font.eot?ver=2.2.1");src:url("http://usapoliticsnow.com/wp-content/plugins/social-warfare/fonts/sw-icon-font.eot?ver=2.2.1#iefix") format("embedded-opentype"),url("http://usapoliticsnow.com/wp-content/plugins/social-warfare/fonts/sw-icon-font.woff?ver=2.2.1") format("woff"), url("http://usapoliticsnow.com/wp-content/plugins/social-warfare/fonts/sw-icon-font.ttf?ver=2.2.1") format("truetype"),url("http://usapoliticsnow.com/wp-content/plugins/social-warfare/fonts/sw-icon-font.svg?ver=2.2.1#1445203416") format("svg");font-weight: normal;font-style: normal;}</style>
# <!-- Social Warfare v2.2.1 http://warfareplugins.com -->
#
#
# <!-- This site is optimized with the Yoast SEO plugin v4.2.1 - https://yoast.com/wordpress/plugins/seo/ -->
# <link rel="canonical" href="http://usapoliticsnow.com/jeff-sessions-tells-pelosi-will-not-back-dc-pedo-investigations/" />
# <meta property="og:locale" content="en_US" />
# <meta property="og:type" content="article" />
# <meta property="og:title" content="Jeff Sessions Tells Pelosi He ‘Will Not Back Down’ From DC Pedo Investigations - USAPoliticsNow" />
# <meta property="og:description" content="A former CIA agent has warned that the deep state is working overtime to oust Attorney General Jeff Sessions from the White House because he is refusing to back down in his campaign to break up the sex trafficking and pedophile networks that control Washington D.C. According to Robert David Steele, Jeff Sessions is being set up &hellip;" />
# <meta property="og:url" content="http://usapoliticsnow.com/jeff-sessions-tells-pelosi-will-not-back-dc-pedo-investigations/" />
# <meta property="og:site_name" content="USAPoliticsNow" />
# <meta property="article:tag" content="Donald Trump" />
# <meta property="article:tag" content="election 2016" />
# <meta property="article:tag" content="Jeff Sessions" />
# <meta property="article:tag" content="President Trump" />
# <meta property="article:tag" content="presidential" />
# <meta property="article:section" content="2016 Election" />
# <meta property="article:published_time" content="2017-03-03T15:14:58+00:00" />
# <meta property="og:image" content="http://usapoliticsnow.com/wp-content/uploads/2017/03/sessions-dc-pedo-investigations-900x350.jpeg" />
# <meta property="og:image:width" content="900" />
# <meta property="og:image:height" content="350" />
# <meta name="twitter:card" content="summary" />
# <meta name="twitter:description" content="A former CIA agent has warned that the deep state is working overtime to oust Attorney General Jeff Sessions from the White House because he is refusing to back down in his campaign to break up the sex trafficking and pedophile networks that control Washington D.C. According to Robert David Steele, Jeff Sessions is being set up [&hellip;]" />
# <meta name="twitter:title" content="Jeff Sessions Tells Pelosi He ‘Will Not Back Down’ From DC Pedo Investigations - USAPoliticsNow" />
# <meta name="twitter:image" content="http://usapoliticsnow.com/wp-content/uploads/2017/03/sessions-dc-pedo-investigations-900x350.jpeg" />
# <!-- / Yoast SEO plugin. -->
#
# <link rel='dns-prefetch' href='//api.content-ad.net' />
# <link rel='dns-prefetch' href='//fonts.googleapis.com' />
# <link rel='dns-prefetch' href='//s.w.org' />
# <link rel="alternate" type="application/rss+xml" title="USAPoliticsNow &raquo; Feed" href="http://usapoliticsnow.com/feed/" />
# 		<script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/2.2.1\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/2.2.1\/svg\/","svgExt":".svg","source":{"concatemoji":"http:\/\/usapoliticsnow.com\/wp-includes\/js\/wp-emoji-release.min.js?ver=4.7.3"}};
# 			!function(a,b,c){function d(a){var b,c,d,e,f=String.fromCharCode;if(!k||!k.fillText)return!1;switch(k.clearRect(0,0,j.width,j.height),k.textBaseline="top",k.font="600 32px Arial",a){case"flag":return k.fillText(f(55356,56826,55356,56819),0,0),!(j.toDataURL().length<3e3)&&(k.clearRect(0,0,j.width,j.height),k.fillText(f(55356,57331,65039,8205,55356,57096),0,0),b=j.toDataURL(),k.clearRect(0,0,j.width,j.height),k.fillText(f(55356,57331,55356,57096),0,0),c=j.toDataURL(),b!==c);case"emoji4":return k.fillText(f(55357,56425,55356,57341,8205,55357,56507),0,0),d=j.toDataURL(),k.clearRect(0,0,j.width,j.height),k.fillText(f(55357,56425,55356,57341,55357,56507),0,0),e=j.toDataURL(),d!==e}return!1}function e(a){var c=b.createElement("script");c.src=a,c.defer=c.type="text/javascript",b.getElementsByTagName("head")[0].appendChild(c)}var f,g,h,i,j=b.createElement("canvas"),k=j.getContext&&j.getContext("2d");for(i=Array("flag","emoji4"),c.supports={everything:!0,everythingExceptFlag:!0},h=0;h<i.length;h++)c.supports[i[h]]=d(i[h]),c.supports.everything=c.supports.everything&&c.supports[i[h]],"flag"!==i[h]&&(c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&c.supports[i[h]]);c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&!c.supports.flag,c.DOMReady=!1,c.readyCallback=function(){c.DOMReady=!0},c.supports.everything||(g=function(){c.readyCallback()},b.addEventListener?(b.addEventListener("DOMContentLoaded",g,!1),a.addEventListener("load",g,!1)):(a.attachEvent("onload",g),b.attachEvent("onreadystatechange",function(){"complete"===b.readyState&&c.readyCallback()})),f=c.source||{},f.concatemoji?e(f.concatemoji):f.wpemoji&&f.twemoji&&(e(f.twemoji),e(f.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# 		<style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link rel='stylesheet' id='contact-form-7-css'  href='http://usapoliticsnow.com/wp-content/plugins/contact-form-7/includes/css/styles.css?ver=4.6.1' type='text/css' media='all' />
# <link rel='stylesheet' id='easy-facebook-likebox-plugin-styles-css'  href='http://usapoliticsnow.com/wp-content/plugins/easy-facebook-likebox/public/assets/css/public.css?ver=4.3.0' type='text/css' media='all' />
# <link rel='stylesheet' id='easy-facebook-likebox-popup-styles-css'  href='http://usapoliticsnow.com/wp-content/plugins/easy-facebook-likebox/public/assets/popup/magnific-popup.css?ver=4.3.0' type='text/css' media='all' />
# <link rel='stylesheet' id='social_warfare-css'  href='http://usapoliticsnow.com/wp-content/plugins/social-warfare/css/style.min.css?ver=2.2.1' type='text/css' media='all' />
# <link rel='stylesheet' id='viral-fonts-css'  href='//fonts.googleapis.com/css?family=Roboto+Condensed:300italic,400italic,700italic,400,300,700|Roboto:300,400,400i,500,700&#038;subset=latin,latin-ext' type='text/css' media='all' />
# <link rel='stylesheet' id='font-awesome-css'  href='http://usapoliticsnow.com/wp-content/themes/viral/css/font-awesome.css?ver=4.6.2' type='text/css' media='all' />
# <link rel='stylesheet' id='owl-carousel-css'  href='http://usapoliticsnow.com/wp-content/themes/viral/css/owl.carousel.css?ver=4.6.2' type='text/css' media='all' />
# <link rel='stylesheet' id='viral-style-css'  href='http://usapoliticsnow.com/wp-content/themes/viral/style.css?ver=4.7.3' type='text/css' media='all' />
# <link rel='stylesheet' id='recent-posts-widget-with-thumbnails-public-style-css'  href='http://usapoliticsnow.com/wp-content/plugins/recent-posts-widget-with-thumbnails/public.css?ver=4.13.3' type='text/css' media='all' />
# <script type='text/javascript' src='http://usapoliticsnow.com/wp-includes/js/jquery/jquery.js?ver=1.12.4'></script>
# <script type='text/javascript' src='http://usapoliticsnow.com/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1'></script>
# <script type='text/javascript' src='http://usapoliticsnow.com/wp-content/plugins/easy-facebook-likebox/public/assets/popup/jquery.magnific-popup.min.js?ver=4.3.0'></script>
# <script type='text/javascript' src='http://usapoliticsnow.com/wp-content/plugins/easy-facebook-likebox/public/assets/js/jquery.cookie.js?ver=4.3.0'></script>
# <script type='text/javascript' src='http://usapoliticsnow.com/wp-content/plugins/easy-facebook-likebox/public/assets/js/public.js?ver=4.3.0'></script>
# <link rel='https://api.w.org/' href='http://usapoliticsnow.com/wp-json/' />
# <link rel="EditURI" type="application/rsd+xml" title="RSD" href="http://usapoliticsnow.com/xmlrpc.php?rsd" />
# <link rel="wlwmanifest" type="application/wlwmanifest+xml" href="http://usapoliticsnow.com/wp-includes/wlwmanifest.xml" />
# <meta name="generator" content="WordPress 4.7.3" />
# <link rel='shortlink' href='http://usapoliticsnow.com/?p=13175' />
# 		<!-- Custom Logo: hide header text -->
# 		<style id="custom-logo-css" type="text/css">
# 			.vl-site-title, .vl-site-description {
# 				position: absolute;
# 				clip: rect(1px, 1px, 1px, 1px);
# 			}
# 		</style>
# 	<link rel="alternate" type="application/json+oembed" href="http://usapoliticsnow.com/wp-json/oembed/1.0/embed?url=http%3A%2F%2Fusapoliticsnow.com%2Fjeff-sessions-tells-pelosi-will-not-back-dc-pedo-investigations%2F" />
# <link rel="alternate" type="text/xml+oembed" href="http://usapoliticsnow.com/wp-json/oembed/1.0/embed?url=http%3A%2F%2Fusapoliticsnow.com%2Fjeff-sessions-tells-pelosi-will-not-back-dc-pedo-investigations%2F&#038;format=xml" />
# <script>
#     (function (i, s, o, g, r, a, m) {
#         i['GoogleAnalyticsObject'] = r;
#         i[r] = i[r] || function () {
#                 (i[r].q = i[r].q || []).push(arguments)
#             }, i[r].l = 1 * new Date();
#         a = s.createElement(o),
#             m = s.getElementsByTagName(o)[0];
#         a.async = 1;
#         a.src = g;
#         m.parentNode.insertBefore(a, m)
#     })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
#
#     ga('create', 'UA-69841390-2', 'auto');
#     ga('send', 'pageview');
# </script>
# <meta name="ca_title" content="Jeff Sessions Tells Pelosi He ‘Will Not Back Down’ From DC Pedo Investigations" /><meta name="ca_image" content="http://usapoliticsnow.com/wp-content/uploads/2017/03/sessions-dc-pedo-investigations-900x350-150x150.jpeg" /><link rel="icon" href="http://usapoliticsnow.com/wp-content/uploads/2016/04/cropped-usalojko-1-1-32x32.jpg" sizes="32x32" />
# <link rel="icon" href="http://usapoliticsnow.com/wp-content/uploads/2016/04/cropped-usalojko-1-1-192x192.jpg" sizes="192x192" />
# <link rel="apple-touch-icon-precomposed" href="http://usapoliticsnow.com/wp-content/uploads/2016/04/cropped-usalojko-1-1-180x180.jpg" />
# <meta name="msapplication-TileImage" content="http://usapoliticsnow.com/wp-content/uploads/2016/04/cropped-usalojko-1-1-270x270.jpg" />
# <!-- PopAds.net Popunder Code for usapoliticsnow.com | 2017-02-14,1813986,0,0 -->
# <script type="text/javascript" data-cfasync="false">
# /*<![CDATA[/* */
#  (function(){ var u=window;u["\u005f\u0070\x6f\x70"]=[["\x73\u0069\u0074\u0065I\u0064",1813986],["\u006di\u006eB\u0069\u0064",0],["\u0070\u006f\x70u\x6e\u0064ers\u0050\x65rI\x50",0],["\x64\u0065\u006ca\u0079\x42\x65\x74w\u0065\x65\u006e",0],["d\x65\u0066\x61u\x6c\u0074",false],["\x64\x65\x66au\u006c\u0074\x50\u0065\u0072\x44\x61y",0],["\x74\u006f\u0070m\u006f\x73\x74\u004c\x61\u0079e\x72",!0]];var l=["\u002f/\u00631.po\x70a\u0064s.n\x65\x74\u002f\u0070op.\x6as","\u002f\u002f\u0063\u0032.p\x6f\x70\x61d\u0073\u002e\u006e\u0065\x74\u002fp\u006f\u0070\u002ej\u0073","/\u002fww\x77\u002e\u006by\x7a\x68e\x63mv\x70\x69\x61\u0077\u002e\u0063\u006f\u006d\x2fx\u006d.j\u0073","//\u0077\u0077\u0077.\x77\x71\x72\u0077\x6fp\u0067kk\u006fh\u006b.\u0063\u006fm\u002f\x72\u0074.js",""],f=0,w,j=function(){if(""==l[f])return;w=u["docum\x65n\u0074"]["\u0063r\x65\u0061\u0074\u0065E\u006c\x65\u006d\x65\x6e\x74"]("\x73c\x72i\u0070\u0074");w["\x74\u0079\x70e"]="\x74\x65\u0078\x74\u002f\x6a\u0061\u0076\u0061s\u0063\x72\x69p\u0074";w["\x61\x73\u0079\x6e\x63"]=!0;var i=u["d\x6fc\u0075\x6d\u0065n\u0074"]["\x67\u0065tE\x6c\x65m\u0065\x6et\u0073\x42y\x54\u0061\x67\x4e\x61m\x65"]("\u0073\u0063\u0072\u0069\u0070\u0074")[0];w["\x73r\x63"]=l[f];if(f<2){w["cr\u006f\x73s\u004fr\x69g\u0069\x6e"]="\x61\x6eo\x6e\u0079\u006d\u006f\x75s";};w["on\u0065r\x72\u006fr"]=function(){f++;j()};i["\u0070\u0061r\x65\u006e\u0074\u004e\x6f\u0064\u0065"]["in\u0073er\x74\u0042\u0065fo\u0072e"](w,i)};j()})();
# /*]]>/* */
# </script>
#
#
# </head>
#
# <body class="post-template-default single single-post postid-13175 single-format-standard wp-custom-logo">
# <div id="vl-page">
# 	<header id="vl-masthead" class="vl-site-header">
# 		<div class="vl-top-header">
# 			<div class="vl-container clearfix">
# 				<div class="vl-top-left-header">
# 									</div>
#
# 				<div class="vl-top-right-header">
# 									</div>
# 			</div>
# 		</div>
#
# 		<div class="vl-header">
# 			<div class="vl-container clearfix">
# 				<div id="vl-site-branding">
# 					<a href="http://usapoliticsnow.com/" class="custom-logo-link" rel="home" itemprop="url"><img width="395" height="84" src="http://usapoliticsnow.com/wp-content/uploads/2016/04/cropped-cropped-usalojko-2-1.jpg" class="custom-logo" alt="" itemprop="logo" srcset="http://usapoliticsnow.com/wp-content/uploads/2016/04/cropped-cropped-usalojko-2-1.jpg 395w, http://usapoliticsnow.com/wp-content/uploads/2016/04/cropped-cropped-usalojko-2-1-300x64.jpg 300w" sizes="(max-width: 395px) 100vw, 395px" /></a>				</div><!-- .site-branding -->
#
# 							</div>
# 		</div>
#
# 		<nav id="vl-site-navigation" class="vl-main-navigation">
# 		<div class="vl-toggle-menu"><span></span></div>
# 			<div class="vl-menu vl-clearfix"><ul id="menu-main" class="vl-clearfix"><li id="menu-item-93" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-home menu-item-93"><a href="http://usapoliticsnow.com">Home</a></li>
# <li id="menu-item-57" class="menu-item menu-item-type-taxonomy menu-item-object-category current-post-ancestor current-menu-parent current-post-parent menu-item-57"><a href="http://usapoliticsnow.com/category/2016-election/">2016 Election</a></li>
# <li id="menu-item-58" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-58"><a href="http://usapoliticsnow.com/category/democrats/">Democrats</a></li>
# <li id="menu-item-59" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-59"><a href="http://usapoliticsnow.com/category/republicans/">Republicans</a></li>
# <li id="menu-item-262" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-262"><a href="http://usapoliticsnow.com/category/video-news/">Video News</a></li>
# <li id="menu-item-9798" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-9798"><a href="http://usapoliticsnow.com/privacy-policy/">Privacy Policy</a></li>
# <li id="menu-item-9813" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-9813"><a href="http://usapoliticsnow.com/contact/">Contact</a></li>
# <li id="menu-item-12549" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-12549"><a href="http://usapoliticsnow.com/home/">Home</a></li>
# </ul></div>		</nav><!-- #vl-site-navigation -->
# 		<img src="http://usapoliticsnow.com/wp-content/themes/viral/images/shadow.png">
# 	</header><!-- #vl-masthead -->
#
# 	<div id="vl-content" class="vl-site-content">
# <div class="vl-container">
# 	<div id="primary" class="content-area">
#
# 		<header class="vl-main-header">
# 			<h1>Jeff Sessions Tells Pelosi He ‘Will Not Back Down’ From DC Pedo Investigations</h1>		</header><!-- .entry-header -->
#
#
#
# <article id="post-13175" class="vl-article-content post-13175 post type-post status-publish format-standard has-post-thumbnail hentry category-2016-election category-us-news tag-donald-trump tag-election-2016 tag-jeff-sessions tag-president-trump tag-presidential">
# 	<header class="entry-header">
# 		<div class="posted-on"><i class="fa fa-clock-o" aria-hidden="true"></i><time class="entry-date published updated" datetime="2017-03-03T15:14:58+00:00">March 3, 2017</time><span class="byline"> by <span class="author vcard">usapoliticsnow admin</span></span></div>	</header>
#
# 	<div class="entry-content">
# 		<div id="contentad280488"></div>
# <p><strong>A former CIA agent has warned that the deep state is working overtime to oust Attorney General Jeff Sessions from the White House because he is refusing to back down in his campaign to break up the sex trafficking and pedophile networks that control Washington D.C.</strong></p>
# <p>According to Robert David Steele, Jeff Sessions is being set up as another “<em>Russian fall guy</em>“, just like General Flynn, to taint the Trump administration and push the president closer to impeachment.</p>
# <p>But most importantly, Steele warns, the deep state is determined to remove the most determined anti-pedophile and -corruption enforcer the office of Attorney General has seen in decades.</p>
# <p>The former CIA agent says that the Democrats push to remove Sessions from office, led by House Minority leader Nancy Pelosi, has “<em>every chance of succeeding</em>” because AG Sessions has made it clear he “<em>will not back down</em>” under any circumstances.</p>
# <p>Federal authorities have locked up more than 1,500 people on child trafficking and pedophilia charges since President Trump and AG Sessions assumed office, however the huge increase in numbers on recent years is being completely ignored by mainstream media.</p>
# <p>According to the FBI there were less than 400 sex trafficking-related arrests made in the entirety of 2014, proving that Trump are Sessions are serious about using “the “<em>full force and weight</em>” of the U.S. government to break up child sex trafficking rings and lock up sexual predators.</p>
# <p>In a hard-hitting <a href="https://www.youtube.com/watch?v=JPYUWx0XyzU">video</a> released late Feburary, Robert David Steele claimed that President Trump is our best chance to take down the deep state since President Kennedy.</p>
# <p>He also claimed that:</p>
# <p>* “White hat” intelligence community was able to stop Hillary from rigging the vote electronically like she did to Bernie</p>
# <p>* Former CIA head John Brennan committed treason by telling lies intended to overturn the Electoral College</p>
# <p>* John Brennan, highest paid agent of Saudi Arabia, should be under FBI investigation</p>
# <p>* Reince Priebus is an enabler and cover-upper of pedophilia — Former Speaker of the House Dennis Hastert is the tip of the iceberg</p>
# <p>* WikiLeaks is going to take down Priebus?</p>
# <p>* <strong>Pedophilia is an “elite privilege” — For the Democrats it’s an “acquired taste” — Podesta is a “pedo-light”</strong></p>
# <p>* The Republicans and the elite in banking are the ones who have made pedophilia a “big league thing”</p>
# <p>* There are Saudi Arabian and Washington DC restaurants with basements where you can order children off of the menu</p>
# <p>* DC pedophilia is the Achilles heel, and Trump has figured that out</p>
# <p>* Flynn didn’t get fired because he called the Russians</p>
# <p>* Flynn got fired because he “had the arrogance to think” (sarcasm) that he could tell Mattis and Tillerson what to do</p>
# <p>* Flynn pissed off VP Pence</p>
# <p>* Flynn’s call that got him in trouble included a conversation about a list of high-level pedophiles inside the US, one of whom happens to be VP Mike Pence’s best friend</p>
# <p>* Flynn did not tell Pence about the list, or that his “best friend” was on it. Pence found out about this from the deep state (probably NSA taps)</p>
# <p>* The NSA has been spying on all of our politicians with impunity!</p>
# <p>* The CIA is leaking HIGHLY classified information as part of a political coup against Trump.</p>
# <p><iframe width="740" height="416" src="https://www.youtube.com/embed/JPYUWx0XyzU?feature=oembed" frameborder="0" allowfullscreen></iframe></p>
# <div id="contentad265941"></div>
# <div class="nc_socialPanel swp_flatFresh swp_d_fullColor swp_i_fullColor swp_o_fullColor scale-100 scale-fullWidth" data-position="below" data-float="floatBottom" data-count="6" data-floatColor="#ffffff" data-emphasize="0"><div class="nc_tweetContainer swp_fb" data-id="3" data-network="facebook"><a rel="nofollow" target="_blank" href="http://www.facebook.com/share.php?u=http%3A%2F%2Fusapoliticsnow.com%2Fjeff-sessions-tells-pelosi-will-not-back-dc-pedo-investigations%2F" data-link="http://www.facebook.com/share.php?u=http%3A%2F%2Fusapoliticsnow.com%2Fjeff-sessions-tells-pelosi-will-not-back-dc-pedo-investigations%2F" class="nc_tweet"><span class="iconFiller"><span class="spaceManWilly"><i class="sw sw-facebook"></i><span class="swp_share"> Share</span></span></span><span class="swp_count">3K</span></a></div><div class="nc_tweetContainer twitter" data-id="2" data-network="twitter"><a rel="nofollow" target="_blank" href="https://twitter.com/share?original_referer=/&text=Jeff+Sessions+Tells+Pelosi+He+%E2%80%98Will+Not+Back+Down%E2%80%99+From+DC+Pedo+Investigations&url=http://usapoliticsnow.com/jeff-sessions-tells-pelosi-will-not-back-dc-pedo-investigations/" data-link="https://twitter.com/share?original_referer=/&text=Jeff+Sessions+Tells+Pelosi+He+%E2%80%98Will+Not+Back+Down%E2%80%99+From+DC+Pedo+Investigations&url=http://usapoliticsnow.com/jeff-sessions-tells-pelosi-will-not-back-dc-pedo-investigations/" class="nc_tweet"><span class="swp_count swp_hide"><span class="iconFiller"><span class="spaceManWilly"><i class="sw sw-twitter"></i><span class="swp_share"> Tweet</span></span></span></span></a></div><div class="nc_tweetContainer googlePlus" data-id="1" data-network="google_plus"><a rel="nofollow" target="_blank" href="https://plus.google.com/share?url=http%3A%2F%2Fusapoliticsnow.com%2Fjeff-sessions-tells-pelosi-will-not-back-dc-pedo-investigations%2F" data-link="https://plus.google.com/share?url=http%3A%2F%2Fusapoliticsnow.com%2Fjeff-sessions-tells-pelosi-will-not-back-dc-pedo-investigations%2F" class="nc_tweet"><span class="swp_count swp_hide"><span class="iconFiller"><span class="spaceManWilly"><i class="sw sw-google-plus"></i><span class="swp_share"> +1</span></span></span></span></a></div><div class="nc_tweetContainer nc_pinterest" data-id="5" data-network="pinterest"><a rel="nofollow" onClick="var e=document.createElement('script');e.setAttribute('type','text/javascript');e.setAttribute('charset','UTF-8');e.setAttribute('src','//assets.pinterest.com/js/pinmarklet.js?r='+Math.random()*99999999);document.body.appendChild(e);" class="nc_tweet noPop"><span class="swp_count swp_hide"><span class="iconFiller"><span class="spaceManWilly"><i class="sw sw-pinterest"></i><span class="swp_share"> Pin</span></span></span></span></a></div><div class="nc_tweetContainer linkedIn" data-id="4" data-network="linked_in"><a rel="nofollow" target="_blank" href="https://www.linkedin.com/cws/share?url=http%3A%2F%2Fusapoliticsnow.com%2Fjeff-sessions-tells-pelosi-will-not-back-dc-pedo-investigations%2F" data-link="https://www.linkedin.com/cws/share?url=http%3A%2F%2Fusapoliticsnow.com%2Fjeff-sessions-tells-pelosi-will-not-back-dc-pedo-investigations%2F" class="nc_tweet"><span class="swp_count swp_hide"><span class="iconFiller"><span class="spaceManWilly"><i class="sw sw-linkedin"></i><span class="swp_share"> Share</span></span></span></span></a></div><div class="nc_tweetContainer swp_stumbleupon" data-id="6" data-network="stumble_upon"><a rel="nofollow" target="_blank" href="http://www.stumbleupon.com/submit?url=http://usapoliticsnow.com/jeff-sessions-tells-pelosi-will-not-back-dc-pedo-investigations/&title=Jeff+Sessions+Tells+Pelosi+He+%E2%80%98Will+Not+Back+Down%E2%80%99+From+DC+Pedo+Investigations" data-link="http://www.stumbleupon.com/submit?url=http://usapoliticsnow.com/jeff-sessions-tells-pelosi-will-not-back-dc-pedo-investigations/&title=Jeff+Sessions+Tells+Pelosi+He+%E2%80%98Will+Not+Back+Down%E2%80%99+From+DC+Pedo+Investigations" class="nc_ ...
#
# 	<footer class="entry-footer">
# 		<div class="cat-links"><i class="fa fa-bookmark"></i> Posted in <a href="http://usapoliticsnow.com/category/2016-election/" rel="category tag">2016 Election</a>, <a href="http://usapoliticsnow.com/category/us-news/" rel="category tag">US News</a></div><div class="tags-links"><i class="fa fa-tag"></i> Tagged <a href="http://usapoliticsnow.com/tag/donald-trump/" rel="tag">Donald Trump</a>, <a href="http://usapoliticsnow.com/tag/election-2016/" rel="tag">election 2016</a>, <a href="http://usapoliticsnow.com/tag/jeff-sessions/" rel="tag">Jeff Sessions</a>, <a href="http://usapoliticsnow.com/tag/president-trump/" rel="tag">President Trump</a>, <a href="http://usapoliticsnow.com/tag/presidential/" rel="tag">presidential</a></div>	</footer><!-- .entry-footer -->
# </article><!-- #post-## -->
#
#
#
# 			<nav class="navigation post-navigation" role="navigation">
# 				<div class="nav-links">
# 					<div class="nav-previous">
# 					<a href="http://usapoliticsnow.com/claims-obama-stole-billions-doj-rock-congress-gop-calling-arrests/" rel="prev"><span><i class="fa fa-angle-left" aria-hidden="true"></i>Prev</span>Claims Obama Stole Billions From DOJ Rock Congress – GOP Calling For Arrests</a>
# 					</div>
#
# 					<div class="nav-next">
# 					<a href="http://usapoliticsnow.com/checkmate-trump-cant-stop-smiling-seeing-just-leaked-obama-russia/" rel="next"><span>Next<i class="fa fa-angle-right" aria-hidden="true"></i></span>CHECKMATE! Trump Can’t Stop Smiling After Seeing What Just Leaked About Obama &#038; Russia!</a>					</div>
# 				</div>
# 			</nav>
#
#
#
# 	</div><!-- #primary -->
#
#
# <div id="secondary" class="widget-area" role="complementary">
# 	<aside id="search-15" class="widget widget_search"><form role="search" method="get" class="search-form" action="http://usapoliticsnow.com/">
# 				<label>
# 					<span class="screen-reader-text">Search for:</span>
# 					<input type="search" class="search-field" placeholder="Search &hellip;" value="" name="s" />
# 				</label>
# 				<input type="submit" class="search-submit" value="Search" />
# 			</form></aside><aside id="easy_facebook_page_plugin-3" class="widget widget_easy_facebook_page_plugin"><h3 class="widget-title">Like Us:</h3><div id="fb-root"></div>
# 					<script>(function(d, s, id) {
# 					  var js, fjs = d.getElementsByTagName(s)[0];
# 					  if (d.getElementById(id)) return;
# 					  js = d.createElement(s); js.id = id;
# 					  js.src = "//connect.facebook.net/en_US/all.js#xfbml=1&appId=395202813876688";
# 					  fjs.parentNode.insertBefore(js, fjs);
# 					}(document, 'script', 'facebook-jssdk'));</script><div class="fb-page " data-href="https://www.facebook.com/usapoliticsnow" data-hide-cover=false data-width="300" data-height="250" data-show-facepile=true  data-show-posts=false data-adapt-container-width=false data-hide-cta=false data-small-header="false"></div></aside><aside id="recent-posts-widget-with-thumbnails-6" class="widget recent-posts-widget-with-thumbnails"><div id="rpwwt-recent-posts-widget-with-thumbnails-6" class="rpwwt-widget">
# 	<h3 class="widget-title">Recent Posts </h3>	<ul>
# 			<li><a href="http://usapoliticsnow.com/200-stranded-marines-needed-get-back-home-heres-trump/"><img width="100" height="100" src="http://usapoliticsnow.com/wp-content/uploads/2017/03/Trump-Marines.001-100x100.jpeg" class="attachment-100x100 size-100x100 wp-post-image" alt="" srcset="http://usapoliticsnow.com/wp-content/uploads/2017/03/Trump-Marines.001-100x100.jpeg 100w, http://usapoliticsnow.com/wp-content/uploads/2017/03/Trump-Marines.001-150x150.jpeg 150w" sizes="(max-width: 100px) 100vw, 100px" /><span class="rpwwt-post-title">200 Stranded Marines Needed To Get Back Home, So Here’s What Trump Did…</span></a></li>
# 			<li><a href="http://usapoliticsnow.com/breaking-three-obama-aides-just-went-witness-protection/"><img width="100" height="100" src="http://usapoliticsnow.com/wp-content/uploads/2017/03/breaking-100x100.jpg" class="attachment-100x100 size-100x100 wp-post-image" alt="" srcset="http://usapoliticsnow.com/wp-content/uploads/2017/03/breaking-100x100.jpg 100w, http://usapoliticsnow.com/wp-content/uploads/2017/03/breaking-150x150.jpg 150w" sizes="(max-width: 100px) 100vw, 100px" /><span class="rpwwt-post-title">BREAKING: Three Obama Aides Just Went Into Witness Protection</span></a></li>
# 			<li><a href="http://usapoliticsnow.com/breaking-obama-investigation-multimillion-dollar-white-house-parties/"><img width="100" height="100" src="http://usapoliticsnow.com/wp-content/uploads/2017/03/Obama-white-house-parties-700x350-100x100.jpg" class="attachment-100x100 size-100x100 wp-post-image" alt="" srcset="http://usapoliticsnow.com/wp-content/uploads/2017/03/Obama-white-house-parties-700x350-100x100.jpg 100w, http://usapoliticsnow.com/wp-content/uploads/2017/03/Obama-white-house-parties-700x350-150x150.jpg 150w" sizes="(max-width: 100px) 100vw, 100px" /><span class="rpwwt-post-title">BREAKING: Obama Under Investigation For Multimillion Dollar White House Parties</span></a></li>
# 			<li><a href="http://usapoliticsnow.com/democrat-congresswoman-just-confirmed-americas-worst-nightmare-trump-right-since-day-one/"><img width="100" height="100" src="http://usapoliticsnow.com/wp-content/uploads/2017/03/break-100x100.jpg" class="attachment-100x100 size-100x100 wp-post-image" alt="" srcset="http://usapoliticsnow.com/wp-content/uploads/2017/03/break-100x100.jpg 100w, http://usapoliticsnow.com/wp-content/uploads/2017/03/break-150x150.jpg 150w" sizes="(max-width: 100px) 100vw, 100px" /><span class="rpwwt-post-title">DEMOCRAT Congresswoman Just CONFIRMED America’s WORST NIGHTMARE – TRUMP WAS RIGHT SINCE DAY ONE!</span></a></li>
# 			<li><a href="http://usapoliticsnow.com/breaking-trump-just-caught-media-red-handed-look-sick-thing/"><img width="100" height="100" src="http://usapoliticsnow.com/wp-content/uploads/2017/03/17160853_10212395224461685_721879302_n-100x100.jpg" class="attachment-100x100 size-100x100 wp-post-image" alt="" srcset="http://usapoliticsnow.com/wp-content/uploads/2017/03/17160853_10212395224461685_721879302_n-100x100.jpg 100w, http://usapoliticsnow.com/wp-content/uploads/2017/03/17160853_10212395224461685_721879302_n-150x150.jpg 150w" sizes="(max-width: 100px) 100vw, 100px" /><span class="rpwwt-post-title">BREAKING: Trump Just Caught The Media Red-Handed! Look at The SICK Thing They Did to Him</span></a></li>
# 		</ul>
# </div><!-- .rpwwt-widget -->
# </aside><aside id="contentad__includes__widget-13" class="widget content-ad-widget">
# <div id="contentad265942"></div>
# </aside></div><!-- #secondary -->
# </div>
#
# 	</div><!-- #content -->
#
# 	<footer id="vl-colophon" class="site-footer">
#
# 	<div class="vl-bottom-footer">
# 		<div class="vl-container">
# 			<div class="vl-site-info">
# 				WordPress Theme
# 				<span class="sep"> | </span>
# 				<a title="Download Viral" href="https://hashthemes.com/wordpress-theme/viral/" target="_blank">Viral</a> by Hash Themes			</div><!-- .site-info -->
# 		</div>
# 	</div>
# 	</footer><!-- #colophon -->
# </div><!-- #page -->
#
# <div id="vl-back-top" class="vl-hide"><i class="fa fa-angle-up" aria-hidden="true"></i></div>
#
# <script type='text/javascript' src='http://usapoliticsnow.com/wp-content/plugins/contact-form-7/includes/js/jquery.form.min.js?ver=3.51.0-2014.06.20'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var _wpcf7 = {"recaptcha":{"messages":{"empty":"Please verify that you are not a robot."}},"cached":"1"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='http://usapoliticsnow.com/wp-content/plugins/contact-form-7/includes/js/scripts.js?ver=4.6.1'></script>
# <script type='text/javascript' src='http://usapoliticsnow.com/wp-content/plugins/social-warfare/js/script.min.js?ver=2.2.1'></script>
# <script type='text/javascript' src='http://usapoliticsnow.com/wp-content/themes/viral/js/SmoothScroll.js?ver=2016427'></script>
# <script type='text/javascript' src='http://usapoliticsnow.com/wp-content/themes/viral/js/owl.carousel.js?ver=2016427'></script>
# <script type='text/javascript' src='http://usapoliticsnow.com/wp-content/themes/viral/js/theia-sticky-sidebar.js?ver=1.4.0'></script>
# <script type='text/javascript' src='http://usapoliticsnow.com/wp-content/themes/viral/js/jquery.superfish.js?ver=2016427'></script>
# <script type='text/javascript' src='http://usapoliticsnow.com/wp-content/themes/viral/js/custom.js?ver=2016427'></script>
# <script type='text/javascript' src='//api.content-ad.net/Scripts/widget2.aspx?id=d0543154-457d-4a48-b661-06d347e4433d&#038;d=dXNhcG9saXRpY3Nub3cuY29t&#038;wid=280488&#038;cb=1.4893501823E+12&#038;ver=1.2.11'></script>
# <script type='text/javascript' src='//api.content-ad.net/Scripts/widget2.aspx?id=dd242350-339d-40d5-bb2a-9fccec576ac0&#038;d=dXNhcG9saXRpY3Nub3cuY29t&#038;wid=265941&#038;cb=1.4893501823E+12&#038;ver=1.2.11'></script>
# <script type='text/javascript' src='http://usapoliticsnow.com/wp-includes/js/wp-embed.min.js?ver=4.7.3'></script>
# <script type='text/javascript' src='//api.content-ad.net/Scripts/widget2.aspx?id=3f60789b-cad1-46e9-bec8-6191a0ce91e1&#038;d=dXNhcG9saXRpY3Nub3cuY29t&#038;wid=265942&#038;cb=1.48935018239E+12&#038;ver=1.2.11'></script>
# <script type="text/javascript">var swpClickTracking = false; var swp_nonce = "0af4016170";		swp_admin_ajax = 'http://usapoliticsnow.com/wp-admin/admin-ajax.php';
# 		var swp_buttons_exist = !!document.getElementsByClassName( 'nc_socialPanel' );
# 		if ( swp_buttons_exist ) {
# 			jQuery( document ).ready( function() {
# 				var swp_cache_data = {
# 					'action': 'swp_cache_trigger',
# 					'post_id': 13175				};
# 				jQuery.post( swp_admin_ajax, swp_cache_data, function( response ) {
# 					console.log(response);
# 				});
# 			});
# 			swp_post_id='13175';
# 			swp_post_url='http://usapoliticsnow.com/jeff-sessions-tells-pelosi-will-not-back-dc-pedo-investigations/';
# 			swp_post_recovery_url = '';
# 			socialWarfarePlugin.fetchShares();
# 		}
# 		</script>
# </body>
# </html>
# <!-- Dynamic page generated in 0.361 seconds. -->
# <!-- Cached page generated by WP-Super-Cache on 2017-03-12 20:23:02 -->
#
# <!-- super cache -->
